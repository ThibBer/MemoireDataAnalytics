# %% [markdown]
# # Likerts

# %%
import os
import pandas as pd
from collections import Counter

def count_occurence(_data):
    counter = Counter(_data)

    occurrences = [0] * 5
    for _index in range(1, 6):
        occurrences[_index - 1] = round(counter.get(_index, 0) / len(_data) * 100, 3)

    return occurrences

likert_out_path = '../../generated/figures/likert'

forms_data_csv_path = '../../generated/forms/data.csv'
likert_questions_csv_path = '../../data/forms/likert_questions.csv'

# %%
if not os.path.exists(forms_data_csv_path):
    raise FileNotFoundError(f"Le fichier {forms_data_csv_path} n'existe pas. Exécutez le notebook 'notebooks/arrange data/Database data.ipynb' pour le générer.")

df_data = pd.read_csv(forms_data_csv_path)
df_data
# Out:
#    Identifiant    group Achievements Horodateur  \
# 0           15        A     17/04/2025 09:32:19
# 1           47        A     17/04/2025 09:32:40
# 2            9        A     17/04/2025 09:32:41
# 3           23        A     17/04/2025 09:32:42
# 4           81        A     17/04/2025 09:32:59
# 5            3        A     17/04/2025 09:33:13
# 6           54        B     17/04/2025 09:33:22
# 7           31        A     17/04/2025 09:33:24
# 8          119        A     17/04/2025 09:33:37
# 9           83        A     17/04/2025 09:33:39
# 10         107        A     17/04/2025 09:33:39
# 11           1        A     17/04/2025 09:33:47
# 12          91        A     17/04/2025 09:33:55
# 13          35        A     17/04/2025 09:34:09
# 14          71        A     17/04/2025 09:34:22
# 15    iessarhi  Invalid     17/04/2025 09:34:37
# 16          73        A     17/04/2025 09:35:16
# 17          32        B     17/04/2025 10:06:54
# 18          28        B     17/04/2025 10:07:02
# 19          92        B     17/04/2025 10:07:11
# 20         104        B     17/04/2025 10:07:20
# 21          48        B     17/04/2025 10:07:24
# 22          68        B     17/04/2025 10:07:38
# 23          36        B     17/04/2025 10:07:39
# 24          30        B     17/04/2025 10:07:42
# 25          72        B     17/04/2025 10:07:45
# 26         100        B     17/04/2025 10:07:51
# 27           8        B     17/04/2025 10:07:55
# 28          96        B     17/04/2025 10:07:57
# 29          42        B     17/04/2025 10:07:57
# 30          70        B     17/04/2025 10:07:57
# 31          56        B     17/04/2025 10:07:58
# 32          50        B     17/04/2025 10:08:00
# 33          26        B     17/04/2025 10:08:05
# 34          40        B     17/04/2025 10:08:10
# 35          52        B     17/04/2025 10:08:27
#
#     A-Facilité d'utilisation du mode achievements  \
# 0                                               4
# 1                                               2
# 2                                               4
# 3                                               4
# 4                                               1
# 5                                               5
# 6                                               1
# 7                                               2
# 8                                               2
# 9                                               4
# 10                                              2
# 11                                              4
# 12                                              4
# 13                                              3
# 14                                              4
# 15                                              1
# 16                                              2
# 17                                              2
# 18                                              4
# 19                                              1
# 20                                              2
# 21                                              1
# 22                                              1
# 23                                              2
# 24                                              4
# 25                                              2
# 26                                              2
# 27                                              2
# 28                                              2
# 29                                              2
# 30                                              3
# 31                                              4
# 32                                              1
# 33                                              1
# 34                                              2
# 35                                              5
#
#     A-Avis sur l'utilisation des achievements  \
# 0                                           5
# 1                                           4
# 2                                           4
# 3                                           3
# 4                                           5
# 5                                           4
# 6                                           2
# 7                                           4
# 8                                           2
# 9                                           4
# 10                                          3
# 11                                          4
# 12                                          4
# 13                                          2
# 14                                          3
# 15                                          4
# 16                                          2
# 17                                          4
# 18                                          2
# 19                                          5
# 20                                          4
# 21                                          4
# 22                                          4
# 23                                          3
# 24                                          3
# 25                                          4
# 26                                          4
# 27                                          3
# 28                                          3
# 29                                          3
# 30                                          2
# 31                                          4
# 32                                          4
# 33                                          5
# 34                                          3
# 35                                          2
#
#     A-Ressenti lors de l'utilisation des achievements ?  \
# 0                                                   2
# 1                                                   2
# 2                                                   2
# 3                                                   3
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                                   2
# 8                                                   2
# 9                                                   2
# 10                                                  3
# 11                                                  2
# 12                                                  3
# 13                                                  2
# 14                                                  3
# 15                                                  2
# 16                                                  4
# 17                                                  2
# 18                                                  2
# 19                                                  1
# 20                                                  1
# 21                                                  2
# 22                                                  2
# 23                                                  4
# 24                                                  4
# 25                                                  3
# 26                                                  2
# 27                                                  2
# 28                                                  4
# 29                                                  3
# 30                                                  3
# 31                                                  4
# 32                                                  2
# 33                                                  1
# 34                                                  3
# 35                                                  3
#
#     A-Ressenti après avoir utilisé les achievements  \
# 0                                                 4
# 1                                                 4
# 2                                                 5
# 3                                                 3
# 4                                                 5
# 5                                                 3
# 6                                                 2
# 7                                                 3
# 8                                                 3
# 9                                                 4
# 10                                                2
# 11                                                4
# 12                                                4
# 13                                                3
# 14                                                3
# 15                                                4
# 16                                                2
# 17                                                4
# 18                                                2
# 19                                                4
# 20                                                5
# 21                                                4
# 22                                                4
# 23                                                3
# 24                                                2
# 25                                                3
# 26                                                4
# 27                                                3
# 28                                                2
# 29                                                3
# 30                                                2
# 31                                                4
# 32                                                3
# 33                                                4
# 34                                                4
# 35                                                3
#
#     A-J'ai été distrait·e à cause des achievements pendant que j'écrivais mes tests ?  \
# 0                                                   2
# 1                                                   3
# 2                                                   3
# 3                                                   4
# 4                                                   1
# 5                                                   2
# 6                                                   1
# 7                                                   4
# 8                                                   1
# 9                                                   3
# 10                                                  2
# 11                                                  1
# 12                                                  4
# 13                                                  1
# 14                                                  3
# 15                                                  3
# 16                                                  4
# 17                                                  2
# 18                                                  4
# 19                                                  3
# 20                                                  2
# 21                                                  2
# 22                                                  1
# 23                                                  4
# 24                                                  2
# 25                                                  1
# 26                                                  1
# 27                                                  1
# 28                                                  4
# 29                                                  1
# 30                                                  2
# 31                                                  2
# 32                                                  2
# 33                                                  2
# 34                                                  2
# 35                                                  3
#
#     A-Motivation à écrire des tests avec le système d'achievements  \
# 0                                                   4
# 1                                                   4
# 2                                                   5
# 3                                                   3
# 4                                                   5
# 5                                                   4
# 6                                                   3
# 7                                                   4
# 8                                                   1
# 9                                                   3
# 10                                                  3
# 11                                                  3
# 12                                                  5
# 13                                                  3
# 14                                                  3
# 15                                                  5
# 16                                                  4
# 17                                                  4
# 18                                                  2
# 19                                                  5
# 20                                                  4
# 21                                                  4
# 22                                                  4
# 23                                                  3
# 24                                                  2
# 25                                                  3
# 26                                                  3
# 27                                                  2
# 28                                                  2
# 29                                                  3
# 30                                                  1
# 31                                                  3
# 32                                                  4
# 33                                                  5
# 34                                                  3
# 35                                                  1
#
#    A-Fréquence de consultation des achievements durant l'évaluation  ...  \
# 0   J'ai consulté les achievements tout le long de...                ...
# 1                                          1 à 5 fois                ...
# 2                                         6 à 10 fois                ...
# 3                                          1 à 5 fois                ...
# 4                                          1 à 5 fois                ...
# 5                                          1 à 5 fois                ...
# 6                                         6 à 10 fois                ...
# 7   J'ai consulté les achievements tout le long de...                ...
# 8                                              Jamais                ...
# 9   J'ai consulté les achievements tout le long de...                ...
# 10  J'ai consulté les achievements tout le long de...                ...
# 11                                         1 à 5 fois                ...
# 12  J'ai consulté les achievements tout le long de...                ...
# 13                                         1 à 5 fois                ...
# 14                                        6 à 10 fois                ...
# 15                                        6 à 10 fois                ...
# 16                                        6 à 10 fois                ...
# 17  J'ai consulté les achievements tout le long de...                ...
# 18                                         1 à 5 fois                ...
# 19                                         1 à 5 fois                ...
# 20                                         1 à 5 fois                ...
# 21  J'ai consulté les achievements tout le long de...                ...
# 22                                        6 à 10 fois                ...
# 23                                        6 à 10 fois                ...
# 24                                         1 à 5 fois                ...
# 25                                             Jamais                ...
# 26  J'ai consulté les achievements tout le long de...                ...
# 27                                         1 à 5 fois                ...
# 28                                        6 à 10 fois                ...
# 29                                Je ne sais pas dire                ...
# 30                                         1 à 5 fois                ...
# 31                                         1 à 5 fois                ...
# 32                                        6 à 10 fois                ...
# 33                                         1 à 5 fois                ...
# 34  J'ai consulté les achievements tout le long de...                ...
# 35                                         1 à 5 fois                ...
#
#     S-Clarté des règles du jeu (achievements, leaderboard)  \
# 0                                                   3
# 1                                                   5
# 2                                                   4
# 3                                                   3
# 4                                                   3
# 5                                                   4
# 6                                                   2
# 7                                                   5
# 8                                                   2
# 9                                                   4
# 10                                                  2
# 11                                                  5
# 12                                                  5
# 13                                                  3
# 14                                                  4
# 15                                                  5
# 16                                                  3
# 17                                                  4
# 18                                                  2
# 19                                                  2
# 20                                                  5
# 21                                                  3
# 22                                                  5
# 23                                                  4
# 24                                                  3
# 25                                                  4
# 26                                                  5
# 27                                                  5
# 28                                                  5
# 29                                                  2
# 30                                                  5
# 31                                                  4
# 32                                                  4
# 33                                                  4
# 34                                                  4
# 35                                                  4
#
#     S-Design et intégration dans IntelliJ  \
# 0                                       5
# 1                                       5
# 2                                       5
# 3                                       3
# 4                                       5
# 5                                       5
# 6                                       5
# 7                                       5
# 8                                       4
# 9                                       4
# 10                                      3
# 11                                      5
# 12                                      4
# 13                                      3
# 14                                      4
# 15                                      4
# 16                                      4
# 17                                      3
# 18                                      4
# 19                                      5
# 20                                      5
# 21                                      5
# 22                                      5
# 23                                      4
# 24                                      4
# 25                                      4
# 26                                      5
# 27                                      4
# 28                                      4
# 29                                      5
# 30                                      5
# 31                                      5
# 32                                      4
# 33                                      4
# 34                                      2
# 35                                      5
#
#     S-Selon vous, quel mode est le plus fun ?  \
# 0                                           1
# 1                                           2
# 2                                           2
# 3                                           5
# 4                                           5
# 5                                           5
# 6                                           3
# 7                                           5
# 8                                           5
# 9                                           4
# 10                                          4
# 11                                          5
# 12                                          5
# 13                                          3
# 14                                          5
# 15                                          2
# 16                                          3
# 17                                          4
# 18                                          3
# 19                                          5
# 20                                          4
# 21                                          5
# 22                                          4
# 23                                          4
# 24                                          2
# 25                                          5
# 26                                          2
# 27                                          1
# 28                                          1
# 29                                          1
# 30                                          2
# 31                                          2
# 32                                          5
# 33                                          5
# 34                                          1
# 35                                          2
#
#    S-Le système de points et de progression vous a-t-il semblé juste ?  \
# 0                                                 Non
# 1                                                 Non
# 2                                                 Oui
# 3                                                 Non
# 4                                                 Oui
# 5                                                 Non
# 6                                                 Oui
# 7                                                 Non
# 8                                                 Oui
# 9                                                 Oui
# 10                                                Oui
# 11                                                Oui
# 12                                                Non
# 13                                                Oui
# 14                                                Non
# 15                                                Non
# 16                                                Non
# 17                                                Non
# 18                                                Non
# 19                                                Oui
# 20                                                Non
# 21                                                Oui
# 22                                                Non
# 23                                                Non
# 24                                                Oui
# 25                                                Oui
# 26                                                Oui
# 27                                                Non
# 28                                                Non
# 29                                                Non
# 30                                                Non
# 31                                                Oui
# 32                                                Oui
# 33                                                Oui
# 34                                                Non
# 35                                                Non
#
#    S-J'ai été tenté d'écrire plus de tests pour augmenter mes points, même si les tests ne sont pas spécialement pertinents  \
# 0                                                   5
# 1                                                   2
# 2                                                   2
# 3                                                   4
# 4                                                   5
# 5                                                   2
# 6                                                   4
# 7                                                   2
# 8                                                   1
# 9                                                   3
# 10                                                  3
# 11                                                  5
# 12                                                  5
# 13                                                  2
# 14                                                  3
# 15                                                  4
# 16                                                  3
# 17                                                  1
# 18                                                  5
# 19                                                  2
# 20                                                  2
# 21                                                  4
# 22                                                  1
# 23                                                  1
# 24                                                  2
# 25                                                  1
# 26                                                  5
# 27                                                  2
# 28                                                  2
# 29                                                  5
# 30                                                  2
# 31                                                  4
# 32                                                  2
# 33                                                  4
# 34                                                  5
# 35                                                  1
#
#    S-Seriez-vous intéressé·e par l'utilisation d'outils gamifiés durant certains cours ?\n(Vérification et Validation, Génie Logiciel, ..)  \
# 0                                                   2
# 1                                                   5
# 2                                                   2
# 3                                                   5
# 4                                                   5
# 5                                                   3
# 6                                                   5
# 7                                                   4
# 8                                                   5
# 9                                                   2
# 10                                                  5
# 11                                                  5
# 12                                                  5
# 13                                                  3
# 14                                                  5
# 15                                                  5
# 16                                                  4
# 17                                                  4
# 18                                                  1
# 19                                                  5
# 20                                                  5
# 21                                                  4
# 22                                                  5
# 23                                                  4
# 24                                                  1
# 25                                                  2
# 26                                                  4
# 27                                                  2
# 28                                                  5
# 29                                                  5
# 30                                                  1
# 31                                                  3
# 32                                                  5
# 33                                                  4
# 34                                                  4
# 35                                                  1
#
#    S-Quel mode j'ai envie d'utiliser dans un cours où je peux être confronté à du test logiciel ? \n(Vérification et Validation, Génie Logiciel, ..)  \
# 0                                                   5
# 1                                                   5
# 2                                                   3
# 3                                                   5
# 4                                                   5
# 5                                                   5
# 6                                                   3
# 7                                                   2
# 8                                                   5
# 9                                                   5
# 10                                                  5
# 11                                                  5
# 12                                                  5
# 13                                                  2
# 14                                                  4
# 15                                                  5
# 16                                                  4
# 17                                                  4
# 18                                                  4
# 19                                                  5
# 20                                                  5
# 21                                                  4
# 22                                                  4
# 23                                                  5
# 24                                                  3
# 25                                                  2
# 26                                                  4
# 27                                                  3
# 28                                                  1
# 29                                                  1
# 30                                                  2
# 31                                                  2
# 32                                                  5
# 33                                                  5
# 34                                                  2
# 35                                                  3
#
#                  S-Donner 3 points positifs du plugin  \
# 0   Facilité d'utilisation, Design agréable, Nous ...
# 1       Pratique, pas compliqué a installé, motivant
# 2       Belle intégration, chouette concept, jolie UI
# 3   Donne un but (récompense) à la création de tes...
# 4   Bien intégré dans Intelliji\nJ'aime vraiment b...
# 5   Intuitif\nSeamless\nUn peu addictif (dans le b...
# 6   - Permet d’étudier en s’amusant \n- facile à u...
# 7               Interactif, compétitif,  divertissant
# 8                                  C’est encourageant
# 9   Belle interface, simple d'utilisation, les not...
# 10  Simple , facile d’utilisation , pratique pour ...
# 11                             stimulant et motivant
# 12  - Simple d'utilisation\n- Bonne gamification\n...
# 13               Simple\nFacile à utilisé \nIntuitif
# 14  Assez simple d'utilisation,\nPlutôt intuitive\...
# 15  fun, drole à utiliser entre potes, donne de l'...
# 16          Intéressant, competitive et enthusiastic
# 17  facile a utiliser\namusant\non voit notre prog...
# 18   design, facilité d'utilisation, mes 40000 points
# 19  Visualisation de la progression, Temps de pris...
# 20  1) Progression visuelle\n2) Poussé à travaille...
# 21            Facile d'utilisation, clair, interactif
# 22                      Ludique \nAmbitieux\nMotivant
# 23                       Fun, stimulant, bien intégré
# 24          L’intégration dans l’IDE / le leaderboard
# 25  Interface sympa, facile à utiliser, achievemen...
# 26            Facile d'utilisation, Amusant, Motivant
# 27           Clair\nFacile à prendre en main\nLudique
# 28            Clair, amusant, interface satisfaisante
# 29         Bien implémenté / amusant / sympa et cool
# 30               Design, facilité d'utilisation, idée
# 31     Le Design, la facilité d'utilisation,   le fun
# 32    Facile, visuel, prend peu de place sur l'écran
# 33              Ludique\nSatisfaisant \nEncourageant
# 34                            Amusant, cool,  design
# 35  on veut écrire des tests, rigolo car il y a de...
#
#                  S-Donner 3 points négatifs du plugin  \
# 0   Le comptage des points peut être "manipulé", J...
# 1   Des gens trichants en réécrivant plusieurs foi...
# 2   Le leaderboard ne s’est pas affiché pendant to...
# 3   Calcul des points à retravailler, j'ai reçu de...
# 4   C'est frustrant d'être battu dans le leader bo...
# 5   Pas claire sur quoi compte\nFacile a exploiter...
# 6                                 Je n’en vois aucun
# 7   peut-être trop divertissant, notifications en ...
# 8                  Il n’y a pas de consignes definies
# 9   Prend beaucoup de taille sur l'ide quand ouver...
# 10                              Je ne peux rien dire
# 11   incitation à faire des tests pas tres utiles ...
# 12  - Leaderboard trop compétitif donc on se retro...
# 13            Pas vraiment de points négatif détecté
# 14  Tout ce qui est ajouts des points en run des t...
# 15  triche possible, certainement pas une bonne id...
# 16      Dans l'ensemble c'est correct rien a rajouté
# 17  possibilité de tricher\nje n'avais pas certain...
# 18  la façon de compter les points, les achievemen...
# 19  Je ne comprends pas toujours comment les point...
# 20  1) Possibilité de triche\n2) Système de points...
# 21  Failles facilement exploitable, peut être un p...
# 22  Permet le spam de test(triche) \nPoint trop ré...
# 23  Buggé (achievements qui ne se valident pas inj...
# 24  Clarté / problème de scroll dans achievement /...
# 25  Trop de système de récompenses, pas toujours i...
# 26  On peut executer plusieurs fois le même test p...
# 27  Trop d'achèvements\nJ'ai eu le sentiment de ne...
# 28  Score manipulable, mauvaise évaluation des tes...
# 29  Score mal foutu / difficulté d’implémenter le ...
# 30  Mauvais systeme de validation, manque de bonne...
# 31                 documentation sur l'utilisation,
# 32  Facilement mis en erreur, possible de tricher,...
# 33  Peut faire perdre de vue l’objectif principal ...
# 34               Score,  installation, mise en place
# 35  il  y a des bugs, pas vrm utile personnelement...
#
#         S-Donner 3 améliorations à apporter au plugin
# 0    Mettre plus d'explications pour les achieveme...
# 1              D’empêcher la triche, et rien de plus
# 2   Bouton pour actualiser le leaderboard, amélior...
# 3   Vérifier le calcul des points du leaderbord me...
# 4                Pouvoir voir les trophées des autres
# 5   Un always on display discret\nUn traqueur de p...
# 6                             Il est parfait pour moi
# 7   Peut-être évaluer la qualité des tests et avoi...
# 8                           Mettre plus de consignes
# 9   Enlever les possibilités de triche, ajouter un...
# 10                                      Pas vraiment
# 11                  Vérifier la pertinence des tests
# 12  - Améliorer la visibilité du leaderboard en fi...
# 13  Amélioration de l interface, Ajout de fonction...
# 14                               Voir points négatifs
# 15                               Empecher la triche\n
# 16         Un peu plus de clarté  sur le leaderboard
# 17  retirer la tricherie\nfaire fonctionner tous l...
# 18  ajoutez une vérification des tests validés pou...
# 19  Critères plus descriptifs, Liens éventuels ver...
# 20  1) Limiter l'obtention de points via les asser...
# 21  Clarification du mode leaderboard, fixer les e...
# 22  Ajouter un mode anti triche\nAjouter une hiéra...
# 23  Améliorer le système de connexion (une seule c...
# 24  Améliorer l’explication des critères / résoudr...
# 25  Amélioration de boards, système équilibré de r...
# 26  Pour chacun des types de tests évalués, Donner...
# 27  Moins d'achèvements (de 1 à 3 par catégories)\...
# 28  Score, évaluation des tests, le mettre directe...
# 29  Le score car possibilité de dupliquer son scor...
# 30                               retirer la tricherie
# 31  La sécurité(authentification), ajouter une exp...
# 32  Notifications plus visibles, aide pour écrire ...
# 33                  Je n’ai pas d’idée sur le moment
# 34  Score pas représentatif, ce serait mieux d'avo...
# 35  régler les bugs, impossible d'envoyer les donn...
#
# [36 rows x 45 columns]

# %%
if not os.path.exists(likert_questions_csv_path):
    raise FileNotFoundError(f"Le fichier {likert_questions_csv_path} n'existe pas. Exécutez le script '../../FormsAppsScripts.gs' dans google drive pour le générer.")

df_likert_questions = pd.read_csv(likert_questions_csv_path, sep=',').drop(columns=['Type'])
df_likert_questions["Titre"] = df_likert_questions["Formulaire"].str[0].str.upper() + "-" + df_likert_questions["Titre"]
df_likert_questions
# Out:
#       Formulaire                                              Titre  \
# 0    demographic                                 D-Compétences java
# 1    demographic                  D-Compétences en écriture de test
# 2    demographic           D-Motivation initiale à écrire des tests
# 3   achievements      A-Facilité d'utilisation du mode achievements
# 4   achievements          A-Avis sur l'utilisation des achievements
# 5   achievements  A-Ressenti lors de l'utilisation des achieveme...
# 6   achievements    A-Ressenti après avoir utilisé les achievements
# 7   achievements  A-J'ai été distrait·e à cause des achievements...
# 8   achievements  A-Motivation à écrire des tests avec le systèm...
# 9   achievements  A-Le système d'achievement m'incite à écrire p...
# 10  achievements  A-Le système d'achievement me permet de voir l...
# 11  achievements  A-Votre intérêt pour un système gamifié avec u...
# 12   leaderboard       L-Facilité d'utilisation du mode leaderboard
# 13   leaderboard            L-Avis sur l'utilisation du leaderboard
# 14   leaderboard    L-Ressenti lors de l'utilisation du leaderboard
# 15   leaderboard      L-Ressenti après avoir utilisé le leaderboard
# 16   leaderboard  L-J'ai été distrait·e à cause du leaderboard p...
# 17   leaderboard  L-Motivation à écrire des tests avec le systèm...
# 18   leaderboard  L-Le système de leaderboard m'incite à écrire ...
# 19   leaderboard  L-Le système de leaderboard me permet de voir ...
# 20   leaderboard  L-Votre intérêt pour un système gamifié avec u...
# 21  satisfaction  S-Après avoir utilisé le plugin,  j'évalue mes...
# 22  satisfaction  S-Après avoir utilisé le plugin, j'évalue ma m...
# 23  satisfaction  S-Clarté des règles du jeu (achievements, lead...
# 24  satisfaction              S-Design et intégration dans IntelliJ
# 25  satisfaction          S-Selon vous, quel mode est le plus fun ?
# 26  satisfaction  S-J'ai été tenté d'écrire plus de tests pour a...
# 27  satisfaction  S-Seriez-vous intéressé·e par l'utilisation d'...
# 28  satisfaction  S-Quel mode j'ai envie d'utiliser dans un cour...
#
#        Label Gauche  Label Droit
# 0        Débutant·e     Expert·e
# 1        Débutant·e     Expert·e
# 2            Faible       Elevée
# 3            Facile    Difficile
# 4          Ennuyeux      Amusant
# 5   Accomplissement  Frustration
# 6         Fatigué·e    Stimulé·e
# 7       Pas du tout  Tout à fait
# 8            Faible       Elevée
# 9       Pas du tout  Tout à fait
# 10      Pas du tout  Tout à fait
# 11      Pas du tout  Tout à fait
# 12           Facile    Difficile
# 13         Ennuyeux      Amusant
# 14  Accomplissement  Frustration
# 15        Fatigué·e    Stimulé·e
# 16      Pas du tout  Tout à fait
# 17           Faible       Elevée
# 18      Pas du tout  Tout à fait
# 19      Pas du tout  Tout à fait
# 20      Pas du tout  Tout à fait
# 21       Débutant·e     Expert·e
# 22           Faible       Elevée
# 23      Pas du tout  Tout à fait
# 24          Mauvais     Très bon
# 25      Leaderboard  Achievement
# 26      Pas du tout  Tout à fait
# 27      Pas du tout  Tout à fait
# 28      Leaderboard  Achievement

# %%
likert_by_label = {}
answers = df_data.transpose()

for index, row in df_likert_questions.iterrows():
    titre = row["Titre"].strip()  # Strip whitespace and newlines
    category = row["Label Gauche"] + "-" + row["Label Droit"]

    if category not in likert_by_label:
        likert_by_label[category] = {}

    if titre in answers.index:  # Check if titre exists in answers index
        likert_by_label[category][titre[2:]] = count_occurence(answers.loc[titre].values.tolist())

# %%
import matplotlib.pyplot as plt
import numpy as np

if not os.path.exists(likert_out_path):
    os.makedirs(likert_out_path)

# Generate 5 light pastel colors in a gradient
colors = ['#FF0000', '#00B050', '#0070C0', '#7030A0', '#FFC000']

for category, results in likert_by_label.items():
    left, right = category.split("-")

    category_names = ['Fortement ' + left.lower(), left, 'Neutre', right, 'Fortement ' + right.lower()]

    labels = ['\n'.join(
        [' '.join(label.strip('? \n').split()[i:i + 6]) for i in range(0, len(label.strip('? \n').split()), 6)]) for
              label in results.keys()]
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    middle_index = data.shape[1] // 2
    offsets = data[:, range(middle_index)].sum(axis=1) + data[:, middle_index] / 2

    num_items = len(labels)
    fig_height = num_items

    fig, ax = plt.subplots(figsize=(10, fig_height))

    # Plot Bars
    for i, (colname, color) in enumerate(zip(category_names, colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths - offsets
        height = 20 / 72  # Convert 20px to inches
        rects = ax.barh(labels, widths, left=starts, height=height, label=colname, color=color)

    # Add Zero Reference Line
    ax.axvline(0, linestyle='--', color='black', alpha=.25)

    # X Axis
    ax.set_xlim(-100, 100)
    ax.set_xticks(np.arange(-100, 101, 10))
    ax.xaxis.set_major_formatter(lambda x, pos: str(abs(int(x))))

    # Add grid
    ax.grid(True, linestyle='--', alpha=0.3)

    # Y Axis
    ax.invert_yaxis()

    # Remove spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)

    # Ledgend
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1), loc='lower left', fontsize='small')

    # Set Background Color
    fig.set_facecolor('#FFFFFF')
    fig.savefig(f"{likert_out_path}/{left}_{right}.png", dpi=300, bbox_inches='tight')

plt.show()
