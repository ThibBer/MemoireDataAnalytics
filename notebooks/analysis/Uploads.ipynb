# %%
import pandas as pd
import os

reports_path = "../../generated/reports-no-bug"

data = []

users = os.listdir(reports_path)
for user in users:
    uploads_path = os.path.join(reports_path, user)
    uploads = os.listdir(uploads_path)
    for upload in uploads:
        path = os.path.join(uploads_path, upload)

        jacoco_path = os.path.join(path, "JaCoCo", "jacoco.csv")
        jacoco_valid = os.path.exists(jacoco_path)

        pitest_path = os.path.join(path, "Pitest", "mutations.xml")
        pitest_valid = os.path.exists(pitest_path)

        data.append([user, upload, jacoco_path, jacoco_valid, pitest_path, pitest_valid])

main_df = pd.DataFrame(data, columns=['user', 'timestamp', 'jacoco', 'jacoco_valid', 'pitest', 'pitest_valid'])
main_df['timestamp'] = pd.to_datetime(main_df['timestamp'], format='%Y-%m-%dT%H-%M-%S.%fZ', utc=True).dt.tz_convert("Europe/Brussels")

# %% [markdown]
# # Add group

# %%
df_users = pd.read_csv('../../generated/database/users.csv', usecols=['user', 'group']).dropna()
main_df = main_df.merge(df_users, on='user', how='left')

# %%
main_df
# Out:
#                                     user                        timestamp  \
# 0   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 09:25:49.752000+02:00
# 1   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 10:07:37.190000+02:00
# 2   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 09:26:18.184000+02:00
# 3   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 10:07:31.004000+02:00
# 4   1d20c70c-aa71-49ff-abf5-6013870a28f8 2025-04-17 09:46:46.781000+02:00
# 5   1d20c70c-aa71-49ff-abf5-6013870a28f8 2025-04-17 10:06:49.533000+02:00
# 6   1f06f352-91b6-4373-87ed-5a5070723efb 2025-04-17 09:26:06.551000+02:00
# 7   1f06f352-91b6-4373-87ed-5a5070723efb 2025-04-17 10:06:44.823000+02:00
# 8   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 09:26:01.215000+02:00
# 9   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 10:06:56.843000+02:00
# 10  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 09:24:52.114000+02:00
# 11  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 10:05:03.689000+02:00
# 12  3e58c347-cdf0-4139-93e0-1adf144753c4 2025-04-17 09:30:22.616000+02:00
# 13  3e58c347-cdf0-4139-93e0-1adf144753c4 2025-04-17 10:06:56.837000+02:00
# 14  465777bf-b8f8-4dbe-b99e-7e1c208be8dc 2025-04-17 09:24:17.593000+02:00
# 15  465777bf-b8f8-4dbe-b99e-7e1c208be8dc 2025-04-17 10:05:03.173000+02:00
# 16  4d14cb87-b95e-4575-8823-f951391a3e6a 2025-04-17 09:25:56.334000+02:00
# 17  4d14cb87-b95e-4575-8823-f951391a3e6a 2025-04-17 10:04:59.677000+02:00
# 18  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 09:24:21.034000+02:00
# 19  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 10:05:22.289000+02:00
# 20  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 09:30:32.138000+02:00
# 21  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 10:06:34.682000+02:00
# 22  674eeeb6-2534-419d-8965-63e4400f60c4 2025-04-17 09:27:59.372000+02:00
# 23  674eeeb6-2534-419d-8965-63e4400f60c4 2025-04-17 10:06:41.999000+02:00
# 24  69f381b2-d619-4968-9db9-ec0e3b10f850 2025-04-17 09:28:09.776000+02:00
# 25  69f381b2-d619-4968-9db9-ec0e3b10f850 2025-04-17 10:04:58.024000+02:00
# 26  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 09:25:49.745000+02:00
# 27  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 10:06:48.693000+02:00
# 28  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17 09:24:22.643000+02:00
# 29  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17 10:05:30.372000+02:00
# 30  7b25b9f2-5d8e-401e-aefa-ac31e94575d1 2025-04-17 09:24:12.395000+02:00
# 31  7b25b9f2-5d8e-401e-aefa-ac31e94575d1 2025-04-17 10:05:04.790000+02:00
# 32  88a83dd8-0ea0-41ad-93ca-d397d796fb37 2025-04-17 09:24:21.326000+02:00
# 33  88a83dd8-0ea0-41ad-93ca-d397d796fb37 2025-04-17 10:05:03.055000+02:00
# 34  9af94b6b-259c-4799-8c79-5960311627bf 2025-04-17 09:26:52.491000+02:00
# 35  9af94b6b-259c-4799-8c79-5960311627bf 2025-04-17 10:05:27.514000+02:00
# 36  a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd 2025-04-17 09:30:06.028000+02:00
# 37  a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd 2025-04-17 10:07:43.975000+02:00
# 38  b39dc415-9bb6-4d5d-a8f9-30fd61f6a594 2025-04-17 09:25:54.925000+02:00
# 39  b39dc415-9bb6-4d5d-a8f9-30fd61f6a594 2025-04-17 10:06:52.695000+02:00
# 40  ca639c6f-a4d1-464c-9b8b-0351617a59b5 2025-04-17 09:24:33.923000+02:00
# 41  ca639c6f-a4d1-464c-9b8b-0351617a59b5 2025-04-17 10:05:02.474000+02:00
# 42  caadbaac-e919-4b9b-b3a5-9d074d40493c 2025-04-17 09:25:50.964000+02:00
# 43  caadbaac-e919-4b9b-b3a5-9d074d40493c 2025-04-17 10:07:10.320000+02:00
# 44  d5082901-d846-4794-82af-2c7db8d50788 2025-04-17 09:25:43.048000+02:00
# 45  d5082901-d846-4794-82af-2c7db8d50788 2025-04-17 10:05:10.780000+02:00
# 46  d65a1736-2d35-44e8-bf24-d1fd976c741f 2025-04-17 09:52:25.973000+02:00
# 47  d65a1736-2d35-44e8-bf24-d1fd976c741f 2025-04-17 10:07:00.722000+02:00
# 48  dbcd3c5d-5f82-4c84-88cc-8a101893e23c 2025-04-17 09:28:21.304000+02:00
# 49  dbcd3c5d-5f82-4c84-88cc-8a101893e23c 2025-04-17 10:17:25.898000+02:00
# 50  de176a06-3fc9-4325-8c81-f131f193c1c4 2025-04-17 09:24:52.737000+02:00
# 51  de176a06-3fc9-4325-8c81-f131f193c1c4 2025-04-17 10:05:20.497000+02:00
# 52  eed81e54-2343-44af-ab2f-cd062db7e11a 2025-04-17 09:24:20.758000+02:00
# 53  eed81e54-2343-44af-ab2f-cd062db7e11a 2025-04-17 10:05:18.858000+02:00
# 54  f08453ce-2b6e-40e4-a0b4-0c37218608fa 2025-04-17 09:26:22.593000+02:00
# 55  f08453ce-2b6e-40e4-a0b4-0c37218608fa 2025-04-17 10:07:41.079000+02:00
# 56  f9ec833e-db4f-49b9-9b14-08298cbb4425 2025-04-17 09:25:10.703000+02:00
# 57  f9ec833e-db4f-49b9-9b14-08298cbb4425 2025-04-17 10:05:10.841000+02:00
#
#                                                jacoco  jacoco_valid  \
# 0   ../../generated/reports-no-bug\0d271530-be17-4...          True
# 1   ../../generated/reports-no-bug\0d271530-be17-4...          True
# 2   ../../generated/reports-no-bug\11b1644a-d11f-4...          True
# 3   ../../generated/reports-no-bug\11b1644a-d11f-4...          True
# 4   ../../generated/reports-no-bug\1d20c70c-aa71-4...         False
# 5   ../../generated/reports-no-bug\1d20c70c-aa71-4...         False
# 6   ../../generated/reports-no-bug\1f06f352-91b6-4...          True
# 7   ../../generated/reports-no-bug\1f06f352-91b6-4...         False
# 8   ../../generated/reports-no-bug\223bf16c-aaad-4...          True
# 9   ../../generated/reports-no-bug\223bf16c-aaad-4...          True
# 10  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True
# 11  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True
# 12  ../../generated/reports-no-bug\3e58c347-cdf0-4...         False
# 13  ../../generated/reports-no-bug\3e58c347-cdf0-4...          True
# 14  ../../generated/reports-no-bug\465777bf-b8f8-4...          True
# 15  ../../generated/reports-no-bug\465777bf-b8f8-4...         False
# 16  ../../generated/reports-no-bug\4d14cb87-b95e-4...         False
# 17  ../../generated/reports-no-bug\4d14cb87-b95e-4...         False
# 18  ../../generated/reports-no-bug\60716858-6fcb-4...          True
# 19  ../../generated/reports-no-bug\60716858-6fcb-4...          True
# 20  ../../generated/reports-no-bug\64330b4a-8b12-4...          True
# 21  ../../generated/reports-no-bug\64330b4a-8b12-4...          True
# 22  ../../generated/reports-no-bug\674eeeb6-2534-4...         False
# 23  ../../generated/reports-no-bug\674eeeb6-2534-4...         False
# 24  ../../generated/reports-no-bug\69f381b2-d619-4...          True
# 25  ../../generated/reports-no-bug\69f381b2-d619-4...         False
# 26  ../../generated/reports-no-bug\70c71a91-06a1-4...          True
# 27  ../../generated/reports-no-bug\70c71a91-06a1-4...          True
# 28  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True
# 29  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True
# 30  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True
# 31  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True
# 32  ../../generated/reports-no-bug\88a83dd8-0ea0-4...          True
# 33  ../../generated/reports-no-bug\88a83dd8-0ea0-4...         False
# 34  ../../generated/reports-no-bug\9af94b6b-259c-4...         False
# 35  ../../generated/reports-no-bug\9af94b6b-259c-4...         False
# 36  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True
# 37  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True
# 38  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True
# 39  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True
# 40  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True
# 41  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True
# 42  ../../generated/reports-no-bug\caadbaac-e919-4...          True
# 43  ../../generated/reports-no-bug\caadbaac-e919-4...          True
# 44  ../../generated/reports-no-bug\d5082901-d846-4...          True
# 45  ../../generated/reports-no-bug\d5082901-d846-4...         False
# 46  ../../generated/reports-no-bug\d65a1736-2d35-4...          True
# 47  ../../generated/reports-no-bug\d65a1736-2d35-4...          True
# 48  ../../generated/reports-no-bug\dbcd3c5d-5f82-4...          True
# 49  ../../generated/reports-no-bug\dbcd3c5d-5f82-4...         False
# 50  ../../generated/reports-no-bug\de176a06-3fc9-4...         False
# 51  ../../generated/reports-no-bug\de176a06-3fc9-4...          True
# 52  ../../generated/reports-no-bug\eed81e54-2343-4...          True
# 53  ../../generated/reports-no-bug\eed81e54-2343-4...          True
# 54  ../../generated/reports-no-bug\f08453ce-2b6e-4...         False
# 55  ../../generated/reports-no-bug\f08453ce-2b6e-4...          True
# 56  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True
# 57  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True
#
#                                                pitest  pitest_valid group
# 0   ../../generated/reports-no-bug\0d271530-be17-4...          True     A
# 1   ../../generated/reports-no-bug\0d271530-be17-4...          True     A
# 2   ../../generated/reports-no-bug\11b1644a-d11f-4...          True     A
# 3   ../../generated/reports-no-bug\11b1644a-d11f-4...          True     A
# 4   ../../generated/reports-no-bug\1d20c70c-aa71-4...         False     A
# 5   ../../generated/reports-no-bug\1d20c70c-aa71-4...         False     A
# 6   ../../generated/reports-no-bug\1f06f352-91b6-4...          True     A
# 7   ../../generated/reports-no-bug\1f06f352-91b6-4...         False     A
# 8   ../../generated/reports-no-bug\223bf16c-aaad-4...          True     A
# 9   ../../generated/reports-no-bug\223bf16c-aaad-4...          True     A
# 10  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True     B
# 11  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True     B
# 12  ../../generated/reports-no-bug\3e58c347-cdf0-4...         False     A
# 13  ../../generated/reports-no-bug\3e58c347-cdf0-4...          True     A
# 14  ../../generated/reports-no-bug\465777bf-b8f8-4...          True     B
# 15  ../../generated/reports-no-bug\465777bf-b8f8-4...         False     B
# 16  ../../generated/reports-no-bug\4d14cb87-b95e-4...         False     B
# 17  ../../generated/reports-no-bug\4d14cb87-b95e-4...         False     B
# 18  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 19  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 20  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 21  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 22  ../../generated/reports-no-bug\674eeeb6-2534-4...         False     A
# 23  ../../generated/reports-no-bug\674eeeb6-2534-4...         False     A
# 24  ../../generated/reports-no-bug\69f381b2-d619-4...          True     B
# 25  ../../generated/reports-no-bug\69f381b2-d619-4...         False     B
# 26  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 27  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 28  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 29  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 30  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 31  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 32  ../../generated/reports-no-bug\88a83dd8-0ea0-4...          True     B
# 33  ../../generated/reports-no-bug\88a83dd8-0ea0-4...         False     B
# 34  ../../generated/reports-no-bug\9af94b6b-259c-4...         False     A
# 35  ../../generated/reports-no-bug\9af94b6b-259c-4...         False     A
# 36  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 37  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 38  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 39  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 40  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 41  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 42  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 43  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 44  ../../generated/reports-no-bug\d5082901-d846-4...          True     B
# 45  ../../generated/reports-no-bug\d5082901-d846-4...         False     B
# 46  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 47  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 48  ../../generated/reports-no-bug\dbcd3c5d-5f82-4...          True     A
# 49  ../../generated/reports-no-bug\dbcd3c5d-5f82-4...         False     A
# 50  ../../generated/reports-no-bug\de176a06-3fc9-4...         False     A
# 51  ../../generated/reports-no-bug\de176a06-3fc9-4...          True     A
# 52  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 53  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 54  ../../generated/reports-no-bug\f08453ce-2b6e-4...         False     A
# 55  ../../generated/reports-no-bug\f08453ce-2b6e-4...          True     A
# 56  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B
# 57  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B

# %% [markdown]
# # Invalid data

# %%
invalid_jacoco = main_df[main_df["jacoco_valid"] == False]
invalid_pitest = main_df[main_df["pitest_valid"] == False]
both_invalid = main_df[(main_df["jacoco_valid"] == False) | (main_df["pitest_valid"] == False)]

print(f"Nombre total d'utilisateurs : {len(df_users)}")
print(f"Nombre total de projets : {len(main_df)}")
print("")

print(f"Nombre de projets invalides JaCoCo :", len(invalid_jacoco), f"({len(invalid_jacoco) / len(main_df) * 100:.2f}%)")
print(f"\t Groupe A : {len(invalid_jacoco[invalid_jacoco['group'] == 'A'])}")
print(f"\t Groupe B : {len(invalid_jacoco[invalid_jacoco['group'] == 'B'])}")
print("")

print(f"Nombre de projets invalides Pitest :", len(invalid_pitest), f"({len(invalid_pitest) / len(main_df) * 100:.2f}%)")
print(f"\t Groupe A : {len(invalid_pitest[invalid_pitest['group'] == 'A'])}")
print(f"\t Groupe B : {len(invalid_pitest[invalid_pitest['group'] == 'B'])}")
print("")

print(f"Nombre de projets invalide (au moins 1 des 2) :", len(both_invalid), f"({len(both_invalid) / len(main_df) * 100:.2f}%)")
print(f"\t Groupe A : {len(both_invalid[both_invalid['group'] == 'A'])}")
print(f"\t Groupe B : {len(both_invalid[both_invalid['group'] == 'B'])}")
# Out:
# Nombre total d'utilisateurs : 39
# Nombre total de projets : 58
#
# Nombre de projets invalides JaCoCo : 17 (29.31%)
# 	 Groupe A : 11
# 	 Groupe B : 6
#
# Nombre de projets invalides Pitest : 17 (29.31%)
# 	 Groupe A : 11
# 	 Groupe B : 6
#
# Nombre de projets invalide (au moins 1 des 2) : 17 (29.31%)
# 	 Groupe A : 11
# 	 Groupe B : 6

# %% [markdown]
# # Both valid

# %%
all_valid = main_df[(main_df["jacoco_valid"] == True) & (main_df["pitest_valid"] == True)]

print(f"Nombre total de projets {len(main_df)} = 2 projets x {int(len(main_df) / 2)} utilisateurs")
print("Nombre de projets valides JaCoCo & Pitest :", len(all_valid), f"({len(all_valid) / len(main_df) * 100:.2f}%)")
print(f"\t Groupe A : {len(all_valid[all_valid['group'] == 'A'])}")
print(f"\t Groupe B : {len(all_valid[all_valid['group'] == 'B'])}")
# Out:
# Nombre total de projets 58 = 2 projets x 29 utilisateurs
# Nombre de projets valides JaCoCo & Pitest : 41 (70.69%)
# 	 Groupe A : 21
# 	 Groupe B : 20

# %% [markdown]
# # User both sessions JaCoCo valid

# %%
cols = ['instruction', 'branch', 'line', 'method']
users_with_timestamps = main_df[(main_df['jacoco_valid'] == True)].groupby('user')['timestamp'].count().reset_index()
jacoco_users_with_2_timestamps = users_with_timestamps[users_with_timestamps['timestamp'] == 2]['user']
jacoco_users = main_df[main_df['user'].isin(jacoco_users_with_2_timestamps)]

print(f"Nombre d'utilisateurs avec 2 rapports JaCoCo valides : {len(jacoco_users_with_2_timestamps)}/{len(users_with_timestamps)}")
# Out:
# Nombre d'utilisateurs avec 2 rapports JaCoCo valides : 16/25
