# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

reports_path = "../../generated/reports-no-bug"

data = []

users = os.listdir(reports_path)
for user in users:
    uploads_path = os.path.join(reports_path, user)
    uploads = os.listdir(uploads_path)
    for upload in uploads:
        path = os.path.join(uploads_path, upload)

        pitest_path = os.path.join(path, "Pitest", "mutations.xml")
        pitest_valid = os.path.exists(pitest_path)

        data.append([user, upload, pitest_path, pitest_valid])


main_df = pd.DataFrame(data, columns=['user', 'timestamp', 'pitest', 'pitest_valid'])
main_df['timestamp'] = pd.to_datetime(main_df['timestamp'], format='%Y-%m-%dT%H-%M-%S.%fZ', utc=True).dt.tz_convert("Europe/Brussels")

# %% [markdown]
# # Add group

# %%
df_users = pd.read_csv('../../generated/database/users.csv', usecols=['user', 'group']).dropna()
main_df = main_df.merge(df_users, on=['user'], how='left')
main_df = main_df.drop(columns=['group_y'], errors='ignore')
main_df = main_df.rename(columns={'group_x': 'group'}, errors='ignore')
main_df
# Out:
#                                     user                        timestamp  \
# 0   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 09:25:49.752000+02:00
# 1   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 10:07:37.190000+02:00
# 2   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 09:26:18.184000+02:00
# 3   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 10:07:31.004000+02:00
# 4   1d20c70c-aa71-49ff-abf5-6013870a28f8 2025-04-17 09:46:46.781000+02:00
# 5   1d20c70c-aa71-49ff-abf5-6013870a28f8 2025-04-17 10:06:49.533000+02:00
# 6   1f06f352-91b6-4373-87ed-5a5070723efb 2025-04-17 09:26:06.551000+02:00
# 7   1f06f352-91b6-4373-87ed-5a5070723efb 2025-04-17 10:06:44.823000+02:00
# 8   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 09:26:01.215000+02:00
# 9   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 10:06:56.843000+02:00
# 10  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 09:24:52.114000+02:00
# 11  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 10:05:03.689000+02:00
# 12  3e58c347-cdf0-4139-93e0-1adf144753c4 2025-04-17 09:30:22.616000+02:00
# 13  3e58c347-cdf0-4139-93e0-1adf144753c4 2025-04-17 10:06:56.837000+02:00
# 14  465777bf-b8f8-4dbe-b99e-7e1c208be8dc 2025-04-17 09:24:17.593000+02:00
# 15  465777bf-b8f8-4dbe-b99e-7e1c208be8dc 2025-04-17 10:05:03.173000+02:00
# 16  4d14cb87-b95e-4575-8823-f951391a3e6a 2025-04-17 09:25:56.334000+02:00
# 17  4d14cb87-b95e-4575-8823-f951391a3e6a 2025-04-17 10:04:59.677000+02:00
# 18  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 09:24:21.034000+02:00
# 19  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 10:05:22.289000+02:00
# 20  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 09:30:32.138000+02:00
# 21  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 10:06:34.682000+02:00
# 22  674eeeb6-2534-419d-8965-63e4400f60c4 2025-04-17 09:27:59.372000+02:00
# 23  674eeeb6-2534-419d-8965-63e4400f60c4 2025-04-17 10:06:41.999000+02:00
# 24  69f381b2-d619-4968-9db9-ec0e3b10f850 2025-04-17 09:28:09.776000+02:00
# 25  69f381b2-d619-4968-9db9-ec0e3b10f850 2025-04-17 10:04:58.024000+02:00
# 26  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 09:25:49.745000+02:00
# 27  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 10:06:48.693000+02:00
# 28  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17 09:24:22.643000+02:00
# 29  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17
../../generated/reports-no-bug\2b2965f7-5d66-4...          True     B
# 12  ../../generated/reports-no-bug\3e58c347-cdf0-4...         False     A
# 13  ../../generated/reports-no-bug\3e58c347-cdf0-4...          True     A
# 14  ../../generated/reports-no-bug\465777bf-b8f8-4...          True     B
# 15  ../../generated/reports-no-bug\465777bf-b8f8-4...         False     B
# 16  ../../generated/reports-no-bug\4d14cb87-b95e-4...         False     B
# 17  ../../generated/reports-no-bug\4d14cb87-b95e-4...         False     B
# 18  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 19  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 20  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 21  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 22  ../../generated/reports-no-bug\674eeeb6-2534-4...         False     A
# 23  ../../generated/reports-no-bug\674eeeb6-2534-4...         False     A
# 24  ../../generated/reports-no-bug\69f381b2-d619-4...          True     B
# 25  ../../generated/reports-no-bug\69f381b2-d619-4...         False     B
# 26  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 27  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 28  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 29  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 30  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 31  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 32  ../../generated/reports-no-bug\88a83dd8-0ea0-4...          True     B
# 33  ../../generated/reports-no-bug\88a83dd8-0ea0-4...         False     B
# 34  ../../generated/reports-no-bug\9af94b6b-259c-4...         False     A
# 35  ../../generated/reports-no-bug\9af94b6b-259c-4...         False     A
# 36  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 37  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 38  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 39  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 40  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 41  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 42  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 43  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 44  ../../generated/reports-no-bug\d5082901-d846-4...          True     B
# 45  ../../generated/reports-no-bug\d5082901-d846-4...         False     B
# 46  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 47  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 48  ../../generated/reports-no-bug\dbcd3c5d-5f82-4...          True     A
# 49  ../../generated/reports-no-bug\dbcd3c5d-5f82-4...         False     A
# 50  ../../generated/reports-no-bug\de176a06-3fc9-4...         False     A
# 51  ../../generated/reports-no-bug\de176a06-3fc9-4...          True     A
# 52  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 53  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 54  ../../generated/reports-no-bug\f08453ce-2b6e-4...         False     A
# 55  ../../generated/reports-no-bug\f08453ce-2b6e-4...          True     A
# 56  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B
# 57  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B

# %% [markdown]
# # Invalid data

# %%
invalid_pitest = main_df[main_df["pitest_valid"] == False]

print(f"Nombre total de projets : {len(main_df)}")
print(f"Nombre de projets valides Pitest :", f"{len(main_df) - len(invalid_pitest)}/{len(main_df)}", f"({(len(main_df) - len(invalid_pitest)) / len(main_df) * 100:.2f}%)")
print(f"Nombre de projets invalides Pitest :", f"{len(invalid_pitest)}/{len(main_df)}", f"({len(invalid_pitest) / len(main_df) * 100:.2f}%)")
print(f"\t Groupe A : {len(invalid_pitest[invalid_pitest['group'] == 'A'])}")
print(f"\t Groupe B : {len(invalid_pitest[invalid_pitest['group'] == 'B'])}")
# Out:
# Nombre total de projets : 58
# Nombre de projets valides Pitest : 41/58 (70.69%)
# Nombre de projets invalides Pitest : 17/58 (29.31%)
# 	 Groupe A : 11
# 	 Groupe B : 6

# %% [markdown]
# # User both sessions Pitest valid

# %%
cols = ['instruction', 'branch', 'line', 'method']
users_count = len(main_df.groupby('user'))
users_with_timestamps = main_df[(main_df['pitest_valid'] == True)].groupby('user')['timestamp'].count().reset_index()
users_with_2_timestamps = users_with_timestamps[users_with_timestamps['timestamp'] == 2]['user']
users = main_df[main_df['user'].isin(users_with_2_timestamps)]

print(f"Nombre d'utilisateurs avec 2 rapports Pitest valides : {len(users_with_2_timestamps)}/{users_count}")
users
# Out:
# Nombre d'utilisateurs avec 2 rapports Pitest valides : 16/29
#                                     user                        timestamp  \
# 0   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 09:25:49.752000+02:00
# 1   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 10:07:37.190000+02:00
# 2   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 09:26:18.184000+02:00
# 3   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 10:07:31.004000+02:00
# 8   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 09:26:01.215000+02:00
# 9   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 10:06:56.843000+02:00
# 10  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 09:24:52.114000+02:00
# 11  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 10:05:03.689000+02:00
# 18  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 09:24:21.034000+02:00
# 19  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 10:05:22.289000+02:00
# 20  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 09:30:32.138000+02:00
# 21  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 10:06:34.682000+02:00
# 26  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 09:25:49.745000+02:00
# 27  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 10:06:48.693000+02:00
# 28  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17 09:24:22.643000+02:00
# 29  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17 10:05:30.372000+02:00
# 30  7b25b9f2-5d8e-401e-aefa-ac31e94575d1 2025-04-17 09:24:12.395000+02:00
# 31  7b25b9f2-5d8e-401e-aefa-ac31e94575d1 2025-04-17 10:05:04.790000+02:00
# 36  a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd 2025-04-17 09:30:06.028000+02:00
# 37  a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd 2025-04-17 10:07:43.975000+02:00
# 38  b39dc415-9bb6-4d5d-a8f9-30fd61f6a594 2025-04-17 09:25:54.925000+02:00
# 39  b39dc415-9bb6-4d5d-a8f9-30fd61f6a594 2025-04-17 10:06:52.695000+02:00
# 40  ca639c6f-a4d1-464c-9b8b-0351617a59b5 2025-04-17 09:24:33.923000+02:00
# 41  ca639c6f-a4d1-464c-9b8b-0351617a59b5 2025-04-17 10:05:02.474000+02:00
# 42  caadbaac-e919-4b9b-b3a5-9d074d40493c 2025-04-17 09:25:50.964000+02:00
# 43  caadbaac-e919-4b9b-b3a5-9d074d40493c 2025-04-17 10:07:10.320000+02:00
# 46  d65a1736-2d35-44e8-bf24-d1fd976c741f 2025-04-17 09:52:25.973000+02:00
# 47  d65a1736-2d35-44e8-bf24-d1fd976c741f 2025-04-17 10:07:00.722000+02:00
# 52  eed81e54-2343-44af-ab2f-cd062db7e11a 2025-04-17 09:24:20.758000+02:00
# 53  eed81e54-2343-44af-ab2f-cd062db7e11a 2025-04-17 10:05:18.858000+02:00
# 56  f9ec833e-db4f-49b9-9b14-08298cbb4425 2025-04-17 09:25:10.703000+02:00
# 57  f9ec833e-db4f-49b9-9b14-08298cbb4425 2025-04-17 10:05:10.841000+02:00
#
#                                                pitest  pitest_valid group
# 0   ../../generated/reports-no-bug\0d271530-be17-4...          True     A
# 1   ../../generated/reports-no-bug\0d271530-be17-4...          True     A
# 2   ../../generated/reports-no-bug\11b1644a-d11f-4...          True     A
# 3   ../../generated/reports-no-bug\11b1644a-d11f-4...          True     A
# 8   ../../generated/reports-no-bug\223bf16c-aaad-4...          True     A
# 9   ../../generated/reports-no-bug\223bf16c-aaad-4...          True     A
# 10  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True     B
# 11  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True     B
# 18  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 19  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 20  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 21  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 26  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 27  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 28  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 29  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 30  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 31  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 36  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 37  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 38  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 39  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 40  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 41  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 42  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 43  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 46  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 47  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 52  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 53  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 56  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B
# 57  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B

# %%
users.loc[:, 'session'] = users.groupby('user')['timestamp'].transform(lambda x: pd.factorize(x)[0] + 1)
users
# Out:
# C:\Users\thiba\AppData\Local\Temp\ipykernel_27208\1516960463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users.loc[:, 'session'] = users.groupby('user')['timestamp'].transform(lambda x: pd.factorize(x)[0] + 1)
#                                     user                        timestamp  \
# 0   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 09:25:49.752000+02:00
# 1   0d271530-be17-4538-bf04-dde3c6069b5f 2025-04-17 10:07:37.190000+02:00
# 2   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 09:26:18.184000+02:00
# 3   11b1644a-d11f-45cb-8a40-282a209059c0 2025-04-17 10:07:31.004000+02:00
# 8   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 09:26:01.215000+02:00
# 9   223bf16c-aaad-404f-8a47-61f3ced741e4 2025-04-17 10:06:56.843000+02:00
# 10  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 09:24:52.114000+02:00
# 11  2b2965f7-5d66-4569-802b-27c84aa69bff 2025-04-17 10:05:03.689000+02:00
# 18  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 09:24:21.034000+02:00
# 19  60716858-6fcb-4953-88e3-12a51b3c7c47 2025-04-17 10:05:22.289000+02:00
# 20  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 09:30:32.138000+02:00
# 21  64330b4a-8b12-4c91-9b78-5942c1b9325f 2025-04-17 10:06:34.682000+02:00
# 26  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 09:25:49.745000+02:00
# 27  70c71a91-06a1-4bf4-8e56-f4327b1c8b3f 2025-04-17 10:06:48.693000+02:00
# 28  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17 09:24:22.643000+02:00
# 29  70e85b5e-92d4-498a-9079-ba881f5b3b82 2025-04-17 10:05:30.372000+02:00
# 30  7b25b9f2-5d8e-401e-aefa-ac31e94575d1 2025-04-17 09:24:12.395000+02:00
# 31  7b25b9f2-5d8e-401e-aefa-ac31e94575d1 2025-04-17 10:05:04.790000+02:00
# 36  a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd 2025-04-17 09:30:06.028000+02:00
# 37  a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd 2025-04-17 10:07:43.975000+02:00
# 38  b39dc415-9bb6-4d5d-a8f9-30fd61f6a594 2025-04-17 09:25:54.925000+02:00
# 39  b39dc415-9bb6-4d5d-a8f9-30fd61f6a594 2025-04-17 10:06:52.695000+02:00
# 40  ca639c6f-a4d1-464c-9b8b-0351617a59b5 2025-04-17 09:24:33.923000+02:00
# 41  ca639c6f-a4d1-464c-9b8b-0351617a59b5 2025-04-17 10:05:02.474000+02:00
# 42  caadbaac-e919-4b9b-b3a5-9d074d40493c 2025-04-17 09:25:50.964000+02:00
# 43  caadbaac-e919-4b9b-b3a5-9d074d40493c 2025-04-17 10:07:10.320000+02:00
# 46  d65a1736-2d35-44e8-bf24-d1fd976c741f 2025-04-17 09:52:25.973000+02:00
# 47  d65a1736-2d35-44e8-bf24-d1fd976c741f 2025-04-17 10:07:00.722000+02:00
# 52  eed81e54-2343-44af-ab2f-cd062db7e11a 2025-04-17 09:24:20.758000+02:00
# 53  eed81e54-2343-44af-ab2f-cd062db7e11a 2025-04-17 10:05:18.858000+02:00
# 56  f9ec833e-db4f-49b9-9b14-08298cbb4425 2025-04-17 09:25:10.703000+02:00
# 57  f9ec833e-db4f-49b9-9b14-08298cbb4425 2025-04-17 10:05:10.841000+02:00
#
#                                                pitest  pitest_valid group  \
# 0   ../../generated/reports-no-bug\0d271530-be17-4...          True     A
# 1   ../../generated/reports-no-bug\0d271530-be17-4...          True     A
# 2   ../../generated/reports-no-bug\11b1644a-d11f-4...          True     A
# 3   ../../generated/reports-no-bug\11b1644a-d11f-4...          True     A
# 8   ../../generated/reports-no-bug\223bf16c-aaad-4...          True     A
# 9   ../../generated/reports-no-bug\223bf16c-aaad-4...          True     A
# 10  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True     B
# 11  ../../generated/reports-no-bug\2b2965f7-5d66-4...          True     B
# 18  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 19  ../../generated/reports-no-bug\60716858-6fcb-4...          True     B
# 20  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 21  ../../generated/reports-no-bug\64330b4a-8b12-4...          True     B
# 26  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 27  ../../generated/reports-no-bug\70c71a91-06a1-4...          True     A
# 28  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 29  ../../generated/reports-no-bug\70e85b5e-92d4-4...          True     B
# 30  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 31  ../../generated/reports-no-bug\7b25b9f2-5d8e-4...          True     B
# 36  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 37  ../../generated/reports-no-bug\a7c1124d-d4fc-4...          True     A
# 38  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 39  ../../generated/reports-no-bug\b39dc415-9bb6-4...          True     A
# 40  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 41  ../../generated/reports-no-bug\ca639c6f-a4d1-4...          True     B
# 42  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 43  ../../generated/reports-no-bug\caadbaac-e919-4...          True     A
# 46  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 47  ../../generated/reports-no-bug\d65a1736-2d35-4...          True     A
# 52  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 53  ../../generated/reports-no-bug\eed81e54-2343-4...          True     B
# 56  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B
# 57  ../../generated/reports-no-bug\f9ec833e-db4f-4...          True     B
#
#     session
# 0         1
# 1         2
# 2         1
# 3         2
# 8         1
# 9         2
# 10        1
# 11        2
# 18        1
# 19        2
# 20        1
# 21        2
# 26        1
# 27        2
# 28        1
# 29        2
# 30        1
# 31        2
# 36        1
# 37        2
# 38        1
# 39        2
# 40        1
# 41        2
# 42        1
# 43        2
# 46        1
# 47        2
# 52        1
# 53        2
# 56        1
# 57        2

# %%
users_pitest_data = []

for _, user_data in users.iterrows():
    user_pitest_df = pd.read_xml(user_data['pitest']).drop(columns=['indexes', 'blocks', 'killingTests', 'succeedingTests', 'coveringTests'])

    users_pitest_data.append(pd.concat([
        pd.DataFrame({
            'user': user_data['user'],
            'group': user_data['group'],
            'session': user_data['session'],
            'timestamp': user_data['timestamp'],
        }, index=user_pitest_df.index),
        user_pitest_df
    ], axis=1))

pitest_data = pd.concat(users_pitest_data, ignore_index=True)
pitest_data
# Out:
#                                       user group  session  \
# 0     0d271530-be17-4538-bf04-dde3c6069b5f     A        1
# 1     0d271530-be17-4538-bf04-dde3c6069b5f     A        1
# 2     0d271530-be17-4538-bf04-dde3c6069b5f     A        1
# 3     0d271530-be17-4538-bf04-dde3c6069b5f     A        1
# 4     0d271530-be17-4538-bf04-dde3c6069b5f     A        1
# ...                                    ...   ...      ...
# 3707  f9ec833e-db4f-49b9-9b14-08298cbb4425     B        2
# 3708  f9ec833e-db4f-49b9-9b14-08298cbb4425     B        2
# 3709  f9ec833e-db4f-49b9-9b14-08298cbb4425     B        2
# 3710  f9ec833e-db4f-49b9-9b14-08298cbb4425     B        2
# 3711  f9ec833e-db4f-49b9-9b14-08298cbb4425     B        2
#
#                             timestamp  detected       status  \
# 0    2025-04-17 09:25:49.752000+02:00     False  NO_COVERAGE
# 1    2025-04-17 09:25:49.752000+02:00     False  NO_COVERAGE
# 2    2025-04-17 09:25:49.752000+02:00     False  NO_COVERAGE
# 3    2025-04-17 09:25:49.752000+02:00     False  NO_COVERAGE
# 4    2025-04-17 09:25:49.752000+02:00     False  NO_COVERAGE
# ...                               ...       ...          ...
# 3707 2025-04-17 10:05:10.841000+02:00     False  NO_COVERAGE
# 3708 2025-04-17 10:05:10.841000+02:00     False  NO_COVERAGE
# 3709 2025-04-17 10:05:10.841000+02:00     False  NO_COVERAGE
# 3710 2025-04-17 10:05:10.841000+02:00      True       KILLED
# 3711 2025-04-17 10:05:10.841000+02:00      True       KILLED
#
#       numberOfTestsRun   sourceFile                            mutatedClass  \
# 0                    0    City.java            be.thibber.gamification.City
# 1                    0    City.java            be.thibber.gamification.City
# 2                    0    City.java            be.thibber.gamification.City
# 3                    0    City.java            be.thibber.gamification.City
# 4                    0    City.java            be.thibber.gamification.City
# ...                ...          ...                                     ...
# 3707                 0    Road.java            be.thibber.gamification.Road
# 3708                 0   House.java  be.thibber.gamification.building.House
# 3709                 0   House.java  be.thibber.gamification.building.House
# 3710                 2  Person.java          be.thibber.gamification.Person
# 3711                 2  Person.java          be.thibber.gamification.Person
#
#                       mutatedMethod      methodDescription  lineNumber  \
# 0               countBuildingByType   (Ljava/lang/Class;)I          72
# 1               countBuildingByType   (Ljava/lang/Class;)I          71
# 2               countBuildingByType   (Ljava/lang/Class;)I          76
# 3     getAvailableParkingSlotsCount                    ()I          87
# 4     getAvailableParkingSlotsCount                    ()I          86
# ...                             ...                    ...         ...
# 3707                    getVehicles     ()Ljava/util/List;          22
# 3708                getTotalSurface                    ()D          17
# 3709                getTotalSurface                    ()D          17
# 3710                         <init>  (Ljava/lang/String;)V           7
# 3711                        getName   ()Ljava/lang/String;          14
#
#                                                 mutator  \
# 0     org.pitest.mutationtest.engine.gregor.mutators...
# 1     org.pitest.mutationtest.engine.gregor.mutators...
# 2     org.pitest.mutationtest.engine.gregor.mutators...
# 3     org.pitest.mutationtest.engine.gregor.mutators...
# 4     org.pitest.mutationtest.engine.gregor.mutators...
# ...                                                 ...
# 3707  org.pitest.mutationtest.engine.gregor.mutators...
# 3708  org.pitest.mutationtest.engine.gregor.mutators...
# 3709  org.pitest.mutationtest.engine.gregor.mutators...
# 3710  org.pitest.mutationtest.engine.gregor.mutators...
# 3711  org.pitest.mutationtest.engine.gregor.mutators...
#
#                                             description
# 0                        Changed increment from 1 to -1
# 1                                   negated conditional
# 2     replaced int return with 0 for be/thibber/gami...
# 3            Replaced integer addition with subtraction
# 4                                   negated conditional
# ...                                                 ...
# 3707  replaced return value with Collections.emptyLi...
# 3708       Replaced double multiplication with division
# 3709  replaced double return with 0.0d for be/thibbe...
# 3710  removed call to be/thibber/gamification/Person...
# 3711  replaced return value with "" for be/thibber/g...
#
# [3712 rows x 14 columns]

# %%
df = pitest_data.groupby(['user', 'group', 'session', 'timestamp', 'sourceFile', 'detected']).size().unstack(fill_value=0)
df.rename(columns={False: 'survived', True: 'killed'}, inplace=True)
df['mutants_count'] = df['survived'] + df['killed']
df['game_mode'] = df.apply(
    lambda row: 'achievements' if (row.name[1] == 'A' and row.name[2] == 1) or ( row.name[1] == 'B' and row.name[2] == 2) else 'leaderboard', axis=1
)
df.to_csv('../../generated/code-analysis/pitest-details.csv', index=True)
df
# Out:
# detected                                                                                           survived  \
# user                                 group session timestamp                        sourceFile
# 0d271530-be17-4538-bf04-dde3c6069b5f A     1       2025-04-17 09:25:49.752000+02:00 Building.java         8
#                                                                                     Car.java             13
#                                                                                     City.java            22
#                                                                                     Coords.java          11
#                                                                                     House.java            2
# ...                                                                                                     ...
# f9ec833e-db4f-49b9-9b14-08298cbb4425 B     2       2025-04-17 10:05:10.841000+02:00 Parking.java         16
#                                                                                     Person.java           0
#                                                                                     PolyLine.java        20
#                                                                                     Road.java             3
#                                                                                     Vehicle.java         11
#
# detected                                                                                           killed  \
# user                                 group session timestamp                        sourceFile
# 0d271530-be17-4538-bf04-dde3c6069b5f A     1       2025-04-17 09:25:49.752000+02:00 Building.java       0
#                                                                                     Car.java            0
#                                                                                     City.java           0
#                                                                                     Coords.java         4
#                                                                                     House.java          0
# ...                                                                                                   ...
# f9ec833e-db4f-49b9-9b14-08298cbb4425 B     2       2025-04-17 10:05:10.841000+02:00 Parking.java        0
#                                                                                     Person.java         2
#                                                                                     PolyLine.java       0
#                                                                                     Road.java           0
#                                                                                     Vehicle.java        4
#
# detected                                                                                           mutants_count  \
# user                                 group session timestamp                        sourceFile
# 0d271530-be17-4538-bf04-dde3c6069b5f A     1       2025-04-17 09:25:49.752000+02:00 Building.java              8
#                                                                                     Car.java                  13
#                                                                                     City.java                 22
#                                                                                     Coords.java               15
#                                                                                     House.java                 2
# ...                                                                                                          ...
# f9ec833e-db4f-49b9-9b14-08298cbb4425 B     2       2025-04-17 10:05:10.841000+02:00 Parking.java              16
#                                                                                     Person.java                2
#                                                                                     PolyLine.java             20
#                                                                                     Road.java                  3
#                                                                                     Vehicle.java              15
#
# detected                                                                                              game_mode
# user                                 group session timestamp                        sourceFile
# 0d271530-be17-4538-bf04-dde3c6069b5f A     1       2025-04-17 09:25:49.752000+02:00 Building.java  achievements
#                                                                                     Car.java       achievements
#                                                                                     City.java      achievements
#                                                                                     Coords.java    achievements
#                                                                                     House.java     achievements
# ...                                                                                                         ...
# f9ec833e-db4f-49b9-9b14-08298cbb4425 B     2       2025-04-17 10:05:10.841000+02:00 Parking.java   achievements
#                                                                                     Person.java    achievements
#                                                                                     PolyLine.java  achievements
#                                                                                     Road.java      achievements
#                                                                                     Vehicle.java   achievements
#
# [320 rows x 4 columns]

# %%
project_data_df = df.groupby(['user', 'group', 'session', 'game_mode', 'timestamp']).sum()
project_data_df['mutation_coverage'] = project_data_df['killed'] / project_data_df['mutants_count']
project_data_df = project_data_df.reset_index()
project_data_df
# Out:
# detected                                  user group  session     game_mode  \
# 0         0d271530-be17-4538-bf04-dde3c6069b5f     A        1  achievements
# 1         0d271530-be17-4538-bf04-dde3c6069b5f     A        2   leaderboard
# 2         11b1644a-d11f-45cb-8a40-282a209059c0     A        1  achievements
# 3         11b1644a-d11f-45cb-8a40-282a209059c0     A        2   leaderboard
# 4         223bf16c-aaad-404f-8a47-61f3ced741e4     A        1  achievements
# 5         223bf16c-aaad-404f-8a47-61f3ced741e4     A        2   leaderboard
# 6         2b2965f7-5d66-4569-802b-27c84aa69bff     B        1   leaderboard
# 7         2b2965f7-5d66-4569-802b-27c84aa69bff     B        2  achievements
# 8         60716858-6fcb-4953-88e3-12a51b3c7c47     B        1   leaderboard
# 9         60716858-6fcb-4953-88e3-12a51b3c7c47     B        2  achievements
# 10        64330b4a-8b12-4c91-9b78-5942c1b9325f     B        1   leaderboard
# 11        64330b4a-8b12-4c91-9b78-5942c1b9325f     B        2  achievements
# 12        70c71a91-06a1-4bf4-8e56-f4327b1c8b3f     A        1  achievements
# 13        70c71a91-06a1-4bf4-8e56-f4327b1c8b3f     A        2   leaderboard
# 14        70e85b5e-92d4-498a-9079-ba881f5b3b82     B        1   leaderboard
# 15        70e85b5e-92d4-498a-9079-ba881f5b3b82     B        2  achievements
# 16        7b25b9f2-5d8e-401e-aefa-ac31e94575d1     B        1   leaderboard
# 17        7b25b9f2-5d8e-401e-aefa-ac31e94575d1     B        2  achievements
# 18        a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd     A        1  achievements
# 19        a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd     A        2   leaderboard
# 20        b39dc415-9bb6-4d5d-a8f9-30fd61f6a594     A        1  achievements
# 21        b39dc415-9bb6-4d5d-a8f9-30fd61f6a594     A        2   leaderboard
# 22        ca639c6f-a4d1-464c-9b8b-0351617a59b5     B        1   leaderboard
# 23        ca639c6f-a4d1-464c-9b8b-0351617a59b5     B        2  achievements
# 24        caadbaac-e919-4b9b-b3a5-9d074d40493c     A        1  achievements
# 25        caadbaac-e919-4b9b-b3a5-9d074d40493c     A        2   leaderboard
# 26        d65a1736-2d35-44e8-bf24-d1fd976c741f     A        1  achievements
# 29                 0.215517
# 30                 0.000000
# 31                 0.077586

# %%
# Get session 1 coverage for each user
session1_coverage = project_data_df[project_data_df['session'] == 1][['user', 'mutation_coverage']]
session1_coverage = session1_coverage.rename(columns={'mutation_coverage': 'session1_coverage'})

# Merge with original dataframe
project_data_df = project_data_df.merge(session1_coverage, on='user', how='left')

# Calculate difference for session 2
project_data_df.loc[project_data_df['session'] == 2, 'mutation_coverage'] = project_data_df.loc[project_data_df['session'] == 2, 'mutation_coverage'] - project_data_df.loc[project_data_df['session'] == 2, 'session1_coverage']

# Drop the temporary column
project_data_df = project_data_df.drop('session1_coverage', axis=1)

project_data_df.to_csv('../../generated/code-analysis/pitest.csv', index=True)

project_data_df
# Out:
# detected                                  user group  session     game_mode  \
# 0         0d271530-be17-4538-bf04-dde3c6069b5f     A        1  achievements
# 1         0d271530-be17-4538-bf04-dde3c6069b5f     A        2   leaderboard
# 2         11b1644a-d11f-45cb-8a40-282a209059c0     A        1  achievements
# 3         11b1644a-d11f-45cb-8a40-282a209059c0     A        2   leaderboard
# 4         223bf16c-aaad-404f-8a47-61f3ced741e4     A        1  achievements
# 5         223bf16c-aaad-404f-8a47-61f3ced741e4     A        2   leaderboard
# 6         2b2965f7-5d66-4569-802b-27c84aa69bff     B        1   leaderboard
# 7         2b2965f7-5d66-4569-802b-27c84aa69bff     B        2  achievements
# 8         60716858-6fcb-4953-88e3-12a51b3c7c47     B        1   leaderboard
# 9         60716858-6fcb-4953-88e3-12a51b3c7c47     B        2  achievements
# 10        64330b4a-8b12-4c91-9b78-5942c1b9325f     B        1   leaderboard
# 11        64330b4a-8b12-4c91-9b78-5942c1b9325f     B        2  achievements
# 12        70c71a91-06a1-4bf4-8e56-f4327b1c8b3f     A        1  achievements
# 13        70c71a91-06a1-4bf4-8e56-f4327b1c8b3f     A        2   leaderboard
# 14        70e85b5e-92d4-498a-9079-ba881f5b3b82     B        1   leaderboard
# 15        70e85b5e-92d4-498a-9079-ba881f5b3b82     B        2  achievements
# 16        7b25b9f2-5d8e-401e-aefa-ac31e94575d1     B        1   leaderboard
# 17        7b25b9f2-5d8e-401e-aefa-ac31e94575d1     B        2  achievements
# 18        a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd     A        1  achievements
# 19        a7c1124d-d4fc-4fc7-bb6f-b73e2f1b7fdd     A        2   leaderboard
# 20        b39dc415-9bb6-4d5d-a8f9-30fd61f6a594     A        1  achievements
# 21        b39dc415-9bb6-4d5d-a8f9-30fd61f6a594     A        2   leaderboard
# 22        ca639c6f-a4d1-464c-9b8b-0351617a59b5     B        1   leaderboard
# 23        ca639c6f-a4d1-464c-9b8b-0351617a59b5     B        2  achievements
# 24        caadbaac-e919-4b9b-b3a5-9d074d40493c     A        1  achievements
# 25        caadbaac-e919-4b9b-b3a5-9d074d40493c     A        2   leaderboard
# 26        d65a1736-2d35-44e8-bf24-d1fd976c741f     A        1  achievements
# 27        d65a1736-2d35-44e8-bf24-d1fd976c741f     A        2   leaderboard
