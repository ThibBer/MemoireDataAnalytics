# %%
import os
import pandas as pd
csv_files_path = "../../data/forms"

forms_generated_path = "../../generated/forms"
if not os.path.exists(forms_generated_path):
    os.makedirs(forms_generated_path)

output_csv_file = f"{forms_generated_path}/data.csv"
invalid_data_csv_file = f"{forms_generated_path}/invalid-data.csv"

csv_files = ["demographic.csv", "achievements.csv", "leaderboard.csv", 'satisfaction.csv']

outer_merged_df = None
inner_merged_df = None
id_key = 'Identifiant'


def group_set(row):
    identifier = row[id_key]

    if identifier.isnumeric():
        return "A" if int(identifier) % 2 != 0 else "B"

    return "Invalid"


for i, csv_file in enumerate(csv_files):
    file_path = os.path.join(csv_files_path, csv_file)
    df = pd.read_csv(file_path, header=0)

    # Rename columns to add file initial
    initial = csv_file[0].upper()
    df.columns = [col if "Horodateur" in col else (f"{initial}-{col}" if col != id_key else col) for col in df.columns]

    duplicated = df[df.duplicated(subset=[id_key], keep=False)]
    duplicated_count = len(duplicated) / 2

    if duplicated_count > 0:
        print(f"⚠️ {csv_file}: {duplicated_count} duplicate(s), keep only firsts")
        print(duplicated[id_key])
        print("")

    df = df.drop_duplicates(subset=[id_key], keep="last")

    if id_key not in df.columns:
        print(f"⚠️ '{id_key}' not found in {csv_file}.")
        print(f"Available columns : {df.columns.tolist()}")
        continue

    if outer_merged_df is None:
        outer_merged_df = df
    else:
        outer_merged_df = pd.merge(outer_merged_df, df, on=id_key, how='outer')

    if inner_merged_df is None:
        inner_merged_df = df
    else:
        inner_merged_df = pd.merge(inner_merged_df, df, on=id_key, how='inner')

inner_merged_df.insert(1, "group", inner_merged_df.apply(group_set, axis=1))
outer_merged_df.insert(1, "group", outer_merged_df.apply(group_set, axis=1))
# Out:
# ⚠️ demographic.csv: 2.0 duplicate(s), keep only firsts
# 33    86
# 39    56
# 42    86
# 43    56
# Name: Identifiant, dtype: object
#
# ⚠️ achievements.csv: 1.0 duplicate(s), keep only firsts
# 20    86
# 41    86
# Name: Identifiant, dtype: object

# %% [markdown]
# ## Differences

# %%
inner_outer_merged_df = pd.merge(inner_merged_df, outer_merged_df, how='outer', indicator=True)

deleted_rows = inner_outer_merged_df[inner_outer_merged_df['_merge'] != 'both']

columns_to_keep = ["Identifiant", "group"] + list(deleted_rows.loc[:, deleted_rows.columns.str.contains("Horodateur")])

not_filled = deleted_rows[columns_to_keep].fillna("Not filled")
not_filled.to_csv(invalid_data_csv_file, index=False)
not_filled
# Out:
#    Identifiant    group Demographic Horodateur Achievements Horodateur  \
# 6            2        B    17/04/2025 08:50:26     17/04/2025 10:07:05
# 16          39        A    17/04/2025 08:48:02              Not filled
# 25          67        A    17/04/2025 08:49:09     17/04/2025 09:33:46
# 27          69        A             Not filled     17/04/2025 09:33:44
# 32          77        A    17/04/2025 08:48:24     17/04/2025 09:34:04
# 35          82        B             Not filled     17/04/2025 10:09:09
# 37          86        B    17/04/2025 09:31:47     17/04/2025 10:09:09
# 42      Selice  Invalid    17/04/2025 08:48:26              Not filled
# 43    hicarlie  Invalid    17/04/2025 08:48:34              Not filled
#
#    Leaderboard Horodateur Satisfaction Horodateur
# 6     17/04/2025 09:31:29              Not filled
# 16             Not filled              Not filled
# 25             Not filled              Not filled
# 27    17/04/2025 10:09:46              Not filled
# 32             Not filled              Not filled
# 35    17/04/2025 09:32:49              Not filled
# 37             Not filled              Not filled
# 42             Not filled              Not filled
# 43    17/04/2025 09:30:56              Not filled

# %% [markdown]
# ## Merged data

# %%
inner_merged_df
# Out:
#    Identifiant    group Demographic Horodateur D-Année d'étude D-Genre  \
# 0            9        A    17/04/2025 08:47:23      Passerelle   Homme
# 1           23        A    17/04/2025 08:47:58      Passerelle   Homme
# 2           36        B    17/04/2025 08:48:03      Passerelle   Homme
# 3            8        B    17/04/2025 08:48:08      Passerelle   Homme
# 4           42        B    17/04/2025 08:48:15           BAC 3   Homme
# 5           47        A    17/04/2025 08:48:17           BAC 3   Homme
# 6          100        B    17/04/2025 08:48:18           BAC 3   Homme
# 7           92        B    17/04/2025 08:48:19           BAC 2   Femme
# 8           71        A    17/04/2025 08:48:21      Passerelle   Homme
# 9          119        A    17/04/2025 08:48:21           BAC 3   Femme
# 10          50        B    17/04/2025 08:48:21           BAC 3   Autre
# 11          91        A    17/04/2025 08:48:23           BAC 3   Homme
# 12          81        A    17/04/2025 08:48:23           BAC 3   Homme
# 13          31        A    17/04/2025 08:48:25      Passerelle   Homme
# 14          68        B    17/04/2025 08:48:28      Passerelle   Homme
# 15          30        B    17/04/2025 08:48:34      Passerelle   Femme
# 16          83        A    17/04/2025 08:48:35           BAC 3   Homme
# 17    iessarhi  Invalid    17/04/2025 08:48:37           BAC 3   Homme
# 18          48        B    17/04/2025 08:48:40           BAC 3   Homme
# 19          40        B    17/04/2025 08:48:40           BAC 3   Femme
# 20          70        B    17/04/2025 08:48:44           BAC 3   Homme
# 21          96        B    17/04/2025 08:48:49           BAC 3   Homme
# 22          26        B    17/04/2025 08:48:52           BAC 3   Homme
# 23           3        A    17/04/2025 08:48:54           BAC 3   Homme
# 24          54        B    17/04/2025 08:48:59           BAC 3   Homme
# 25          73        A    17/04/2025 08:49:05           BAC 3   Homme
# 26           1        A    17/04/2025 08:49:09           BAC 3   Femme
# 27          28        B    17/04/2025 08:49:10           BAC 3   Homme
# 28         107        A    17/04/2025 08:49:12           BAC 3   Homme
# 29          15        A    17/04/2025 08:49:14           BAC 3   Femme
# 30         104        B    17/04/2025 08:49:16           BAC 3   Homme
# 31          32        B    17/04/2025 08:49:24           BAC 2   Homme
# 32          72        B    17/04/2025 08:49:50      Passerelle   Homme
# 33          35        A    17/04/2025 08:53:07           BAC 3   Homme
# 34          56        B    17/04/2025 09:32:26      Passerelle   Femme
# 35          52        B    17/04/2025 09:32:30           BAC 3   Homme
#
#                     D-Outils gamifiés déjà utilisés ?  D-Compétences java  \
# 0                                   Duolingo, Kahoot!                   4
# 1                                   Duolingo, Kahoot!                   4
# 2                                   Duolingo, Kahoot!                   4
# 3                                            Duolingo                   4
# 4                                   Duolingo, Kahoot!                   2
# 5   Duolingo, Kahoot!, CodeCombat, GitHub Achievem...                   4
# 6                                            Duolingo                   2
# 7                                   Duolingo, Kahoot!                   3
# 8                                   Duolingo, Kahoot!                   4
# 9                                            Duolingo                   1
# 10                                                NaN                   3
# 11                                  Duolingo, Kahoot!                   2
# 12                                  Duolingo, Kahoot!                   2
# 13                                  Duolingo, Kahoot!                   4
# 14                                           Duolingo                   3
# 15                                                NaN                   3
# 16                                  Duolingo, Kahoot!                   3
# 17                                  Duolingo, Kahoot!                   3
# 18                                  Duolingo, Kahoot!                   3
# 19                                           Duolingo                   2
# 20                                 codewars ou moins)                   3
# 21                                                NaN                   2
# 22                                                NaN                   2
# 23                                                NaN                   2
# 24                                           Duolingo                   1
# 25                                            Kahoot!                   3
# 26                                  Duolingo, Kahoot!                   3
# 27                                  Duolingo, Kahoot!                   2
# 28                                           Duolingo                   2
# 29                                  Duolingo, Kahoot!                   3
# 30                                                NaN                   3
# 31                                                NaN                   3
# 32                                           Duolingo                   3
# 33                                           Duolingo                   2
# 34                                GitHub Achievements                   3
# 35                                  Duolingo, Kahoot!                   3
#
#     D-Compétences en écriture de test  \
# 0                                   4
# 1                                   4
# 2                                   3
# 3                                   3
# 4                                   2
# 5                                   2
# 6                                   1
# 7                                   2
# 8                                   3
# 9                                   2
# 10                                  2
# 11                                  3
# 12                                  2
# 13                                  2
# 14                                  3
# 15                                  3
# 16                                  3
# 17                                  2
# 18                                  2
# 19                                  2
# 20                                  3
# 21                                  2
# 22                                  1
# 23                                  3
# 24                                  1
# 25                                  3
# 26                                  3
# 27                                  1
# 28                                  3
# 29                                  1
# 30                                  3
# 31                                  3
# 32                                  2
# 33                                  3
# 34                                  3
# 35                                  2
#
#     D-Motivation initiale à écrire des tests Achievements Horodateur  ...  \
# 0                                          4     17/04/2025 09:32:41  ...
# 1                                          3     17/04/2025 09:32:42  ...
# 2                                          4     17/04/2025 10:07:39  ...
# 3                                          2     17/04/2025 10:07:55  ...
# 4                                          1     17/04/2025 10:07:57  ...
# 5                                          2     17/04/2025 09:32:40  ...
# 6                                          3     17/04/2025 10:07:51  ...
# 7                                          3     17/04/2025 10:07:11  ...
# 8                                          2     17/04/2025 09:34:22  ...
# 9                                          1     17/04/2025 09:33:37  ...
# 10                                         4     17/04/2025 10:08:00  ...
# 11                                         1     17/04/2025 09:33:55  ...
# 12                                         4     17/04/2025 09:32:59  ...
# 13                                         2     17/04/2025 09:33:24  ...
# 14                                         3     17/04/2025 10:07:38  ...
# 15                                         3     17/04/2025 10:07:42  ...
# 16                                         4     17/04/2025 09:33:39  ...
# 17                                         1     17/04/2025 09:34:37  ...
# 18                                         1     17/04/2025 10:07:24  ...
# 19                                         1     17/04/2025 10:08:10  ...
# 20                                         3     17/04/2025 10:07:57  ...
# 21                                         1     17/04/2025 10:07:57  ...
# 22                                         2     17/04/2025 10:08:05  ...
# 23                                         3     17/04/2025 09:33:13  ...
# 24                                         1     17/04/2025 09:33:22  ...
# 25                                         4     17/04/2025 09:35:16  ...
# 26                                         4     17/04/2025 09:33:47  ...
# 27                                         3     17/04/2025 10:07:02  ...
# 28                                         2     17/04/2025 09:33:39  ...
# 29                                         2     17/04/2025 09:32:19  ...
# 30                                         3     17/04/2025 10:07:20  ...
# 31                                         2     17/04/2025 10:06:54  ...
# 32                                         4     17/04/2025 10:07:45  ...
# 33                                         2     17/04/2025 09:34:09  ...
# 34                                         3     17/04/2025 10:07:58  ...
# 35                                         1     17/04/2025 10:08:27  ...
#
#     S-Clarté des règles du jeu (achievements, leaderboard)  \
# 0                                                   4
# 1                                                   3
# 2                                                   4
# 3                                                   5
# 4                                                   2
# 5                                                   5
# 6                                                   5
# 7                                                   2
# 8                                                   4
# 9                                                   2
# 10                                                  4
# 11                                                  5
# 12                                                  3
# 13                                                  5
# 14                                                  5
# 15                                                  3
# 16                                                  4
# 17                                                  5
# 18                                                  3
# 19                                                  4
# 20                                                  5
# 21                                                  5
# 22                                                  4
# 23                                                  4
# 24                                                  2
# 25                                                  3
# 26                                                  5
# 27                                                  2
# 28                                                  2
# 29                                                  3
# 30                                                  5
# 31                                                  4
# 32                                                  4
# 33                                                  3
# 34                                                  4
# 35                                                  4
#
#     S-Design et intégration dans IntelliJ  \
# 0                                       5
# 1                                       3
# 2                                       4
# 3                                       4
# 4                                       5
# 5                                       5
# 6                                       5
# 7                                       5
# 8                                       4
# 9                                       4
# 10                                      4
# 11                                      4
# 12                                      5
# 13                                      5
# 14                                      5
# 15                                      4
# 16                                      4
# 17                                      4
# 18                                      5
# 19                                      2
# 20                                      5
# 21                                      4
# 22                                      4
# 23                                      5
# 24                                      5
# 25                                      4
# 26                                      5
# 27                                      4
# 28                                      3
# 29                                      5
# 30                                      5
# 31                                      3
# 32                                      4
# 33                                      3
# 34                                      5
# 35                                      5
#
#     S-Selon vous, quel mode est le plus fun ?  \
# 0                                           2
# 1                                           5
# 2                                           4
# 3                                           1
# 4                                           1
# 5                                           2
# 6                                           2
# 7                                           5
# 8                                           5
# 9                                           5
# 10                                          5
# 11                                          5
# 12                                          5
# 13                                          5
# 14                                          4
# 15                                          2
# 16                                          4
# 17                                          2
# 18                                          5
# 19                                          1
# 20                                          2
# 21                                          1
# 22                                          5
# 23                                          5
# 24                                          3
# 25                                          3
# 26                                          5
# 27                                          3
# 28                                          4
# 29                                          1
# 30                                          4
# 31                                          4
# 32                                          5
# 33                                          3
# 34                                          2
# 35                                          2
#
#     S-Le système de points et de progression vous a-t-il semblé juste ?  \
# 0                                                 Oui
# 1                                                 Non
# 2                                                 Non
# 3                                                 Non
# 4                                                 Non
# 5                                                 Non
# 6                                                 Oui
# 7                                                 Oui
# 8                                                 Non
# 9                                                 Oui
# 10                                                Oui
# 11                                                Non
# 12                                                Oui
# 13                                                Non
# 14                                                Non
# 15                                                Oui
# 16                                                Oui
# 17                                                Non
# 18                                                Oui
# 19                                                Non
# 20                                                Non
# 21                                                Non
# 22                                                Oui
# 23                                                Non
# 24                                                Oui
# 25                                                Non
# 26                                                Oui
# 27                                                Non
# 28                                                Oui
# 29                                                Non
# 30                                                Non
# 31                                                Non
# 32                                                Oui
# 33                                                Oui
# 34                                                Oui
# 35                                                Non
#
#     S-J'ai été tenté d'écrire plus de tests pour augmenter mes points, même si les tests ne sont pas spécialement pertinents  \
# 0                                                   2
# 1                                                   4
# 2                                                   1
# 3                                                   2
# 4                                                   5
# 5                                                   2
# 6                                                   5
# 7                                                   2
# 8                                                   3
# 9                                                   1
# 10                                                  2
# 11                                                  5
# 12                                                  5
# 13                                                  2
# 14                                                  1
# 15                                                  2
# 16                                                  3
# 17                                                  4
# 18                                                  4
# 19                                                  5
# 20                                                  2
# 21                                                  2
# 22                                                  4
# 23                                                  2
# 24                                                  4
# 25                                                  3
# 26                                                  5
# 27                                                  5
# 28                                                  3
# 29                                                  5
# 30                                                  2
# 31                                                  1
# 32                                                  1
# 33                                                  2
# 34                                                  4
# 35                                                  1
#
#     S-Seriez-vous intéressé·e par l'utilisation d'outils gamifiés durant certains cours ?\n(Vérification et Validation, Génie Logiciel, ..)  \
# 0                                                   2
# 1                                                   5
# 2                                                   4
# 3                                                   2
# 4                                                   5
# 5                                                   5
# 6                                                   4
# 7                                                   5
# 8                                                   5
# 9                                                   5
# 10                                                  5
# 11                                                  5
# 12                                                  5
# 13                                                  4
# 14                                                  5
# 15                                                  1
# 16                                                  2
# 17                                                  5
# 18                                                  4
# 19                                                  4
# 20                                                  1
# 21                                                  5
# 22                                                  4
# 23                                                  3
# 24                                                  5
# 25                                                  4
# 26                                                  5
# 27                                                  1
# 28                                                  5
# 29                                                  2
# 30                                                  5
# 31                                                  4
# 32                                                  2
# 33                                                  3
# 34                                                  3
# 35                                                  1
#
#    S-Quel mode j'ai envie d'utiliser dans un cours où je peux être confronté à du test logiciel ? \n(Vérification et Validation, Génie Logiciel, ..)  \
# 0                                                   3
# 1                                                   5
# 2                                                   5
# 3                                                   3
# 4                                                   1
# 5                                                   5
# 6                                                   4
# 7                                                   5
# 8                                                   4
# 9                                                   5
# 10                                                  5
# 11                                                  5
# 12                                                  5
# 13                                                  2
# 14                                                  4
# 15                                                  3
# 16                                                  5
# 17                                                  5
# 18                                                  4
# 19                                                  2
# 20                                                  2
# 21                                                  1
# 22                                                  5
# 23                                                  5
# 24                                                  3
# 25                                                  4
# 26                                                  5
# 27                                                  4
# 28                                                  5
# 29                                                  5
# 30                                                  5
# 31                                                  4
# 32                                                  2
# 33                                                  2
# 34                                                  2
# 35                                                  3
#
#                  S-Donner 3 points positifs du plugin  \
# 0       Belle intégration, chouette concept, jolie UI
# 1   Donne un but (récompense) à la création de tes...
# 2                        Fun, stimulant, bien intégré
# 3            Clair\nFacile à prendre en main\nLudique
# 4          Bien implémenté / amusant / sympa et cool
# 5       Pratique, pas compliqué a installé, motivant
# 6             Facile d'utilisation, Amusant, Motivant
# 7   Visualisation de la progression, Temps de pris...
# 8   Assez simple d'utilisation,\nPlutôt intuitive\...
# 9                                  C’est encourageant
# 10    Facile, visuel, prend peu de place sur l'écran
# 11  - Simple d'utilisation\n- Bonne gamification\n...
# 12  Bien intégré dans Intelliji\nJ'aime vraiment b...
# 13              Interactif, compétitif,  divertissant
# 14                      Ludique \nAmbitieux\nMotivant
# 15          L’intégration dans l’IDE / le leaderboard
# 16  Belle interface, simple d'utilisation, les not...
# 17  fun, drole à utiliser entre potes, donne de l'...
# 18            Facile d'utilisation, clair, interactif
# 19                            Amusant, cool,  design
# 20               Design, facilité d'utilisation, idée
# 21            Clair, amusant, interface satisfaisante
# 22              Ludique\nSatisfaisant \nEncourageant
# 23  Intuitif\nSeamless\nUn peu addictif (dans le b...
# 24  - Permet d’étudier en s’amusant \n- facile à u...
# 25          Intéressant, competitive et enthusiastic
# 26                             stimulant et motivant
# 27   design, facilité d'utilisation, mes 40000 points
# 28  Simple , facile d’utilisation , pratique pour ...
# 29  Facilité d'utilisation, Design agréable, Nous ...
# 30  1) Progression visuelle\n2) Poussé à travaille...
# 31  facile a utiliser\namusant\non voit notre prog...
# 32  Interface sympa, facile à utiliser, achievemen...
# 33               Simple\nFacile à utilisé \nIntuitif
# 34     Le Design, la facilité d'utilisation,   le fun
# 35  on veut écrire des tests, rigolo car il y a de...
#
#                  S-Donner 3 points négatifs du plugin  \
# 0   Le leaderboard ne s’est pas affiché pendant to...
# 1   Calcul des points à retravailler, j'ai reçu de...
# 2   Buggé (achievements qui ne se valident pas inj...
# 3   Trop d'achèvements\nJ'ai eu le sentiment de ne...
# 4   Score mal foutu / difficulté d’implémenter le ...
# 5   Des gens trichants en réécrivant plusieurs foi...
# 6   On peut executer plusieurs fois le même test p...
# 7   Je ne comprends pas toujours comment les point...
# 8   Tout ce qui est ajouts des points en run des t...
# 9                  Il n’y a pas de consignes definies
# 10  Facilement mis en erreur, possible de tricher,...
# 11  - Leaderboard trop compétitif donc on se retro...
# 12  C'est frustrant d'être battu dans le leader bo...
# 13  peut-être trop divertissant, notifications en ...
# 14  Permet le spam de test(triche) \nPoint trop ré...
# 15  Clarté / problème de scroll dans achievement /...
# 16  Prend beaucoup de taille sur l'ide quand ouver...
# 17  triche possible, certainement pas une bonne id...
# 18  Failles facilement exploitable, peut être un p...
# 19               Score,  installation, mise en place
# 20  Mauvais systeme de validation, manque de bonne...
# 21  Score manipulable, mauvaise évaluation des tes...
# 22  Peut faire perdre de vue l’objectif principal ...
# 23  Pas claire sur quoi compte\nFacile a exploiter...
# 24                                Je n’en vois aucun
# 25      Dans l'ensemble c'est correct rien a rajouté
# 26   incitation à faire des tests pas tres utiles ...
# 27  la façon de compter les points, les achievemen...
# 28                              Je ne peux rien dire
# 29  Le comptage des points peut être "manipulé", J...
# 30  1) Possibilité de triche\n2) Système de points...
# 31  possibilité de tricher\nje n'avais pas certain...
# 32  Trop de système de récompenses, pas toujours i...
# 33            Pas vraiment de points négatif détecté
# 34                 documentation sur l'utilisation,
# 35  il  y a des bugs, pas vrm utile personnelement...
#
#         S-Donner 3 améliorations à apporter au plugin
# 0   Bouton pour actualiser le leaderboard, amélior...
# 1   Vérifier le calcul des points du leaderbord me...
# 2   Améliorer le système de connexion (une seule c...
# 3   Moins d'achèvements (de 1 à 3 par catégories)\...
# 4   Le score car possibilité de dupliquer son scor...
# 5              D’empêcher la triche, et rien de plus
# 6   Pour chacun des types de tests évalués, Donner...
# 7   Critères plus descriptifs, Liens éventuels ver...
# 8                                Voir points négatifs
# 9                           Mettre plus de consignes
# 10  Notifications plus visibles, aide pour écrire ...
# 11  - Améliorer la visibilité du leaderboard en fi...
# 12               Pouvoir voir les trophées des autres
# 13  Peut-être évaluer la qualité des tests et avoi...
# 14  Ajouter un mode anti triche\nAjouter une hiéra...
# 15  Améliorer l’explication des critères / résoudr...
# 16  Enlever les possibilités de triche, ajouter un...
# 17                               Empecher la triche\n
# 18  Clarification du mode leaderboard, fixer les e...
# 19  Score pas représentatif, ce serait mieux d'avo...
# 20                               retirer la tricherie
# 21  Score, évaluation des tests, le mettre directe...
# 22                  Je n’ai pas d’idée sur le moment
# 23  Un always on display discret\nUn traqueur de p...
# 24                            Il est parfait pour moi
# 25         Un peu plus de clarté  sur le leaderboard
# 26                  Vérifier la pertinence des tests
# 27  ajoutez une vérification des tests validés pou...
# 28                                      Pas vraiment
# 29   Mettre plus d'explications pour les achieveme...
# 30  1) Limiter l'obtention de points via les asser...
# 31  retirer la tricherie\nfaire fonctionner tous l...
# 32  Amélioration de boards, système équilibré de r...
# 33  Amélioration de l interface, Ajout de fonction...
# 34  La sécurité(authentification), ajouter une exp...
# 35  régler les bugs, impossible d'envoyer les donn...
#
# [36 rows x 45 columns]

# %% [markdown]
# # Fix user with non numeric identifiers

# %%
invalid_id_df = inner_merged_df[~inner_merged_df[id_key].str.isnumeric()].copy()
invalid_id_df.loc[:, 'Achievements Horodateur'] = pd.to_datetime(invalid_id_df['Achievements Horodateur'], format='%d/%m/%Y %H:%M:%S', utc=False)
invalid_id_df
# Out:
#    Identifiant    group Demographic Horodateur D-Année d'étude D-Genre  \
# 17    iessarhi  Invalid    17/04/2025 08:48:37           BAC 3   Homme
#
#    D-Outils gamifiés déjà utilisés ?  D-Compétences java  \
# 17                 Duolingo, Kahoot!                   3
#
#     D-Compétences en écriture de test  \
# 17                                  2
#
#     D-Motivation initiale à écrire des tests Achievements Horodateur  ...  \
# 17                                         1     2025-04-17 09:34:37  ...
#
#     S-Clarté des règles du jeu (achievements, leaderboard)  \
# 17                                                  5
#
#     S-Design et intégration dans IntelliJ  \
# 17                                      4
#
#     S-Selon vous, quel mode est le plus fun ?  \
# 17                                          2
#
#     S-Le système de points et de progression vous a-t-il semblé juste ?  \
# 17                                                Non
#
#     S-J'ai été tenté d'écrire plus de tests pour augmenter mes points, même si les tests ne sont pas spécialement pertinents  \
# 17                                                  4
#
#     S-Seriez-vous intéressé·e par l'utilisation d'outils gamifiés durant certains cours ?\n(Vérification et Validation, Génie Logiciel, ..)  \
# 17                                                  5
#
#    S-Quel mode j'ai envie d'utiliser dans un cours où je peux être confronté à du test logiciel ? \n(Vérification et Validation, Génie Logiciel, ..)  \
# 17                                                  5
#
#                  S-Donner 3 points positifs du plugin  \
# 17  fun, drole à utiliser entre potes, donne de l'...
#
#                  S-Donner 3 points négatifs du plugin  \
# 17  triche possible, certainement pas une bonne id...
#
#     S-Donner 3 améliorations à apporter au plugin
# 17                           Empecher la triche\n
#
# [1 rows x 45 columns]

# %% [markdown]
# # Strange data

# %% [markdown]
# ## B group user first filled the achievements form

# %%
inner_merged_df['Achievements Horodateur'] = pd.to_datetime(inner_merged_df['Achievements Horodateur'], format='%d/%m/%Y %H:%M:%S', utc=False)
invalid_b_group = inner_merged_df[(inner_merged_df['group'] == 'B') & (pd.to_datetime(inner_merged_df['Achievements Horodateur']) < pd.to_datetime('2025-04-17 10:00:00'))][['Identifiant', 'group', 'Achievements Horodateur']]
invalid_b_group
# Out:
#    Identifiant group Achievements Horodateur
# 24          54     B     2025-04-17 09:33:22

# %% [markdown]
# ## A group user first filled the leaderboard form

# %%
inner_merged_df['Leaderboard Horodateur'] = pd.to_datetime(inner_merged_df['Leaderboard Horodateur'], format='%d/%m/%Y %H:%M:%S', utc=False)
inner_merged_df[(inner_merged_df['group'] == 'A') & (pd.to_datetime(inner_merged_df['Leaderboard Horodateur']) < pd.to_datetime('2025-04-17 10:00:00'))][['Identifiant', 'group', 'Leaderboard Horodateur']]
# Out:
# Empty DataFrame
# Columns: [Identifiant, group, Leaderboard Horodateur]
# Index: []

# %% [markdown]
# ## Save to csv

# %%
inner_merged_df.to_csv(output_csv_file, index=False)
print(f"Merged forms data save at {output_csv_file}")
# Out:
# Merged forms data save at ../../generated/forms/data.csv
